# %%
import pandas as pd
import numpy as np
import re

import matplotlib.pyplot as plt

# %%
def import_data(file_name, parsed=True):
    if not parsed:
        parser(file_name,output_name=file_name.split(".")[0])
        file_name = file_name.split(".")[0]+".txt"
    
    data = open(f"{file_name}", 'r', encoding='utf-8').read()
    pairs = [token.split('\t') for token in data.split('\n')]
    
    return pairs

# %%
# !ls
# Out:
#  a.txt                  data_dist.ipynb    __pycache__
# 'Data Analysis.ipynb'   model_output.txt

# %%
wiki_pairs = import_data('/home/kara/Documents/Courses/Fall 2021/LING412 - RESEARCH & WRITING/Datasets/Phonological/wiki_data_p.txt')
web_pairs = import_data("/home/kara/Documents/Courses/Fall 2021/LING412 - RESEARCH & WRITING/Datasets/Phonological/web_data_p.txt")

# %%
wiki_pairs[214]
# Out:
# ["boğazI'NDA",
#  'boğaz+NOUN+PersonNumber=A3sg+Possessive=P3sg+Apostrophe=True+Case=Loc+Proper=True']

# %%
def get_tag_counts(pairs):
    try:
        morphs = [token[1] for token in pairs]
    except:
        morphs = [token[1] for token in pairs[:-1]]

    pos = [token.split(" ")[1] for token in morphs if token != "?"]
    feats = [token.split(" ")[2:] for token in morphs]
    feat_extend = []
    for feat in feats:
        feat_extend.extend(feat)

    return pd.Series(pos).value_counts(), pd.Series(feat_extend).value_counts()

# %%
import json

morphology = json.loads(open("/home/kara/Documents/Courses/Fall 2021/LING412 - RESEARCH & WRITING/source/morphology.json", "r", encoding='utf-8').read())

# %%
from string import punctuation
print(re.escape(punctuation))
# Out:
# !"\#\$%\&'\(\)\*\+,\-\./:;<=>\?@\[\\\]\^_`\{\|\}\~

# %%
def lemma_norm(lemma):
    if lemma.endswith("k"):
        return lemma[:-1]+"[kğ]"
    if lemma.endswith("t"):
        return lemma[:-1]+"[td]"
    if lemma.endswith("p"):
        return lemma[:-1]+"[pb]"
    else:
        return lemma

# %%
import sys
def phonological(instance):
    token = re.escape(instance[0].lower())

    feats = instance[1]

    lemma = re.escape(feats.split("+")[0])
    norm = lemma_norm(lemma)

    token_select = token[:len(lemma)]+"("+token[len(lemma):]+")"

    try:
        f_list = feats.split("+")[2:]

        for feat in f_list:

            def wrap(term):

                token = term.group(2)
                prev = term.group(1)
                if len(morphology[feat]) == 4:
                    regex_morph1, regex_sub1,regex_morph2, regex_sub2 = morphology[feat]
                    token = re.sub(regex_morph1, regex_sub1, token)
                    token = re.sub(regex_morph2, regex_sub2, token)

                elif len(morphology[feat]) == 6:
                    regex_morph1, regex_sub1,regex_morph2, regex_sub2, regex_morph3, regex_sub3 = morphology[feat]
                    token = re.sub(regex_morph1, regex_sub1, token)
                    token = re.sub(regex_morph2, regex_sub2, token)
                    token = re.sub(regex_morph3, regex_sub3, token)

                else:
                    regex_morph, regex_sub = morphology[feat]
                    token = re.sub(regex_morph, regex_sub, token)

                return prev+token

            token = re.sub("("+token[:len(lemma)]+")("+token[len(lemma):]+")", wrap, token)
    except:
        print(token,feats)

    return (token, instance[1])

# %%
phonological(wiki_pairs[110])
# Out:
# ('\\.', '.+PUNCT')

# %%
wiki_pairs_p = [phonological(p) for p in wiki_pairs]
web_pairs_p = [phonological(p) for p in web_pairs]
# Out:
# i̇ng\. ing.+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare

# %%
print(wiki_pairs_p[0])
# Out:
# ('kemerlArINI', 'kemer+NOUN+PersonNumber=A3sg+Possessive=P3pl+Case=Acc')

# %%
with open("/home/kara/Documents/Courses/Fall 2021/LING412 - RESEARCH & WRITING/Datasets/Phonological/wiki_data_p.txt","w+", encoding="utf-8") as f_out:
    for token, feat in wiki_pairs_p:
        print(token,feat)
        f_out.write(f"{token}\t{feat}\n")
    
with open("/home/kara/Documents/Courses/Fall 2021/LING412 - RESEARCH & WRITING/Datasets/Phonological/web_data_p.txt","w+", encoding="utf-8") as f_out:
    for token, feat in web_pairs_p:
        f_out.write(f"{token}\t{feat}\n")
# Out:
# kemerlArINI kemer+NOUN+PersonNumber=A3sg+Possessive=P3pl+Case=Acc
# aralık aralık+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# ayINDA ay+NOUN+Temporal=True+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# ki ki+X
# armageddon'DA armageddon+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Loc+Proper=True
# dört dört+NUM
# takımIn takım+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Gen
# katılDIKI katıl+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg
# eliminasyon eliminasyon+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# maçINDA maç+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# booker booker+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# t t+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# ve ve+CONJ+ConjunctionType=Coor
# goldust'A goldust+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Dat+Proper=True
# kaybetDIlAr kaybet+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl
# \. .+PUNCT
# birlAşmIş bir+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True+Derivation=Bcm+Polarity=Pos+Proper=True+Derivation=PerPart+Possessive=Pnon+Proper=True
# milletlAr'A millet+NOUN+PersonNumber=A3pl+Apostrophe=True+Case=Dat+Proper=True
# göre göre+ADP^CDat+Possessive=Pnon+Case=Bare
# , ,+PUNCT
# 2025 2025+NUM
# yılInA yıl+NOUN+Temporal=True+PersonNumber=A3sg+Possessive=P3sg+Case=Dat
# gelInDIKINDA gel+VERB+Derivation=Pass+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# afrika afrika+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom+Proper=True
# sadece sadece+ADJ
# nüfusInIn nüfus+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Gen
# % %+X
# 25'InI 25+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=P3sg+Case=Acc
# besleyAbilAcAkDIr besle+VERB+Derivation=Able+Polarity=Pos+TenseAspectMood=Fut+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# grup grup+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# yönetimInIn yönetim+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Gen
# önceki önce+ADV+Temporal=True+Derivation=Rel
# itirazlArInDAn itiraz+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Abl
# sonra sonra+ADP^CAbl+Possessive=Pnon+Case=Bare
# 12 12+NUM
# haziran'DA haziran+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# lee lee+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# troy troy+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# mclawhorn mclawhorn+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# un un+X+Case=Gen+Proper=True
# gitarist gitar+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Foll+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# olErEK ol+VERB+Polarity=Pos+Derivation=Ger
# grubA grup+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# katılDIKInI katıl+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc
# teyit teyit+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# etDI et+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# ancak ancak+CONJ+ConjunctionType=Adv
# genel genel+ADJ
# algınIn algı+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Gen
# aksinA aksi+ADP^CGen+Possessive=P3sg+Case=Dat
# , ,+PUNCT
# runik runik+ADJ
# taşlArIn taş+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Gen
# büyük büyük+ADJ
# bölümIm bölüm+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# , ,+PUNCT
# evINDA ev+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# ölAnlAr öl+VERB+Polarity=Pos+Derivation=PresNom+PersonNumber=A3pl+Possessive=Pnon+Case=Bare
# için için+ADP^CBare+Possessive=Pnon+Case=Bare
# dikIlmIşDIr dik+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3pl
# \. .+PUNCT
# ortodoks ortodoks+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# dinadamlArI dinadam+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Bare
# ve ve+CONJ+ConjunctionType=Coor
# rabinik rabinik+ADJ
# yetkilIlAr yetki+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With+PersonNumber=A3pl+Possessive=Pnon+Case=Nom
# genel genel+ADJ
# olErEK ol+VERB+Polarity=Pos+Derivation=Ger
# tapınağIn tapınak+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Gen
# yahudi yahudi+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# mesih mesih+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom+Proper=True
# gelDIKI gel+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# zaman zaman+ADP^CBare+Possessive=Pnon+Case=Bare
# tanrı'nIn tanrı+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Gen+Proper=True
# elIYlA el+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Ins
# inşa inşa+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# edIlAcAKInA et+VERB+Derivation=Pass+Polarity=Pos+Derivation=FutNom+PersonNumber=A3sg+Possessive=P3sg+Case=Dat
# inansA inan+VERB+Polarity=Pos+TenseAspectMood=Desr+Copula=PresCop+PersonNumber=V3pl
# da da+PRT
# , ,+PUNCT
# az az+DET^Ind
# sayıDA sayı+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# inanAn inan+VERB+Polarity=Pos+Derivation=PresNom+PersonNumber=A3sg+Possessive=Pnon+Case=Nom
# rambam'In rambam+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Gen+Proper=True
# fikirlArInI fikir+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Acc
# takip takip+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# edIp et+VERB+Polarity=Pos+Derivation=After
# mümkün mümkün+ADJ
# olAn ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# bir bir+DET^Ind
# zamanDA zaman+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# kendilArI kendi+PRON+PersonNumber=A3sg+Possessive=P3pl+Case=Bare
# tarafInDAn taraf+ADP^CBare+Possessive=P3sg+Case=Abl
# inşa inşa+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# edIlmAsI et+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# gerekDIKInI gerek+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc
# savunmAktaDIr savun+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3pl
# \. .+PUNCT
# ayni aynı+ADJ
# mezhepDAn mezhep+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Abl
# olmAnIn ol+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Gen
# avantajI avantaj+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# ve ve+CONJ+ConjunctionType=Coor
# korunmA koru+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# içgüdüsI içgüdü+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# ile ile+ADP^CBare+Possessive=Pnon+Case=Bare
# birbirlerinA birbiri+PRON+PersonNumber=A3sg+Possessive=P3pl+Case=Dat
# yaklaşmIşlAr yaklaş+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=PresCop+PersonNumber=V3pl
# \. .+PUNCT
# her her+DET^Def
# gök gök+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# cismi cisim+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# , ,+PUNCT
# odak odak+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# noktalArInDAn nokta+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Abl
# birINDA bir+PRON+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# güneş'In güneş+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Gen+Proper=True
# bulunDIKI bulun+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg
# yaklaşık yaklaşık+ADJ
# bir bir+DET^Ind
# elips elips+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# yörünge yörünge+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# üzerINDA üzer+ADP^CBare+Possessive=P3sg+Case=Loc
# hareket hareket+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# edIr et+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# yıldızlArI yıldız+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Acc
# ve ve+CONJ+ConjunctionType=Coor
# diğer diğer+DET^Ind
# gökcisimlArInI gökcismi+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Acc
# adlAnDIrmA ad+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Acq+Derivation=Cau+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# konusINDA konu+ADP^CBare+Possessive=P3sg+Case=Loc
# bilimsAl bilim+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Rtd
# toplulukDA topluluk+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# tek tek+DET^Def
# yetkilI yetki+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With
# kurum kurum+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom
# uluslararası uluslararası+ADJ+Proper=True
# astronomi astronomi+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# birlIKI'dIr bir+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True+Derivation=Ness+PersonNumber=A3sg+Possessive=P3sg+Apostrophe=True+Case=Bare+Copula=GenCop+PersonNumber=V3sg+Proper=True
# \( (+PUNCT
# `` ``+PUNCT
# international ınternational+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# astronomical astronomical+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# union union+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# \- -+PUNCT
# iau ıau+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# '' ''+PUNCT
# \) )+PUNCT
# \. .+PUNCT
# gözlemlAnebIlIr gözlem+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Make+Derivation=Pass+Derivation=Able+Polarity=Pos+Derivation=AorPart+Possessive=Pnon
# evren evren+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom
# 93 93+NUM
# milyar milyar+NUM
# ışık ışık+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# yılI yıl+NOUN+Temporal=True+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# , ,+PUNCT
# \( (+PUNCT
# 8,8 8,8+NUM
# × ×+X
# 10 10+NUM
# metre metre+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# \) )+PUNCT
# genişlIKINDAdIr geniş+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Ness+PersonNumber=A3sg+Possessive=P3sg+Case=Loc+Copula=GenCop+PersonNumber=V3sg
# ve ve+CONJ+ConjunctionType=Coor
# yaklaşık yaklaşık+ADJ
# 125 125+NUM
# milyar milyar+NUM
# \( (+PUNCT
# 1,25 1,25+NUM
# × ×+X
# 10 10+NUM
# \) )+PUNCT
# galaksi galaksi+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# içINDAkI iç+ADP^CBare+Possessive=P3sg+Case=Loc+Derivation=Rel
# 5 5+NUM
# × ×+X
# 10 10+NUM
# yıldızDAn yıldız+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Abl
# oluşIr oluş+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# lazarethane'DA lazarethane+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Loc+Proper=True
# sadrâzam sadrâzam+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# koca koca+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# yûsuf yûsuf+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# paşa paşa+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# başkanlIKINDA başkan+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Ness+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# yapIlAn yap+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# ordu ordu+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# müzakerelArINDA müzakere+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Loc
# kış kış+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# mevsimI mevsim+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# ciddiyetlA ciddiyet+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Ins
# başlamAdan başla+VERB+Polarity=Neg+Derivation=Ger
# ve ve+CONJ+ConjunctionType=Coor
# avusturya avusturya+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# ordusInIn ordu+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Gen
# muhaddiye muhaddiye+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# muharebesI muharebe+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Proper=True
# yenilgisInDAn yenilgi+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Abl
# kendiNI kendi+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Acc
# toparlamAsInA toparla+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Dat
# imkan imkan+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# sağlamAdan sağla+VERB+Polarity=Neg+Derivation=Ger
# , ,+PUNCT
# hemen hemen+ADV
# harekatA harekat+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# başlanmAsInA başla+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Dat
# ve ve+CONJ+ConjunctionType=Coor
# bu bu+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# nedenlA neden+ADP^CBare+Possessive=Pnon+Case=Ins
# şebeş şebeş+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# boğazI'NDA boğaz+NOUN+PersonNumber=A3sg+Possessive=P3sg+Apostrophe=True+Case=Loc+Proper=True
# tahkimlI tahkim+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With
# mevzilArA mevzi+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Dat
# girmIş gir+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=PresCop+PersonNumber=V3sg
# olAn ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# avusturya avusturya+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# ordusI ordu+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# üzerInA üzer+ADP^CBare+Possessive=P3sg+Case=Dat
# gidIlmAsInA git+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Dat
# karar karar+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom
# verIlDI ver+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# scrum scrum+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# ustasInIn usta+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Gen
# kim kim+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# olAcAKInIn ol+VERB+Polarity=Pos+Derivation=FutNom+PersonNumber=A3sg+Possessive=P3sg+Case=Gen
# belirlenmAsInIn belirle+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Gen
# en en+ADV
# ideal ideal+ADJ
# yolI yol+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# yazılım yazılım+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# takımI takım+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# tarafInDAn taraf+ADP^CBare+Possessive=P3sg+Case=Abl
# seçIlmAsIdIr seç+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# 1950'lArIn 1950+NOUN+Apostrophe=True+PersonNumber=A3pl+Possessive=Pnon+Case=Gen
# sonINDA son+ADP^CGen+Possessive=P3sg+Case=Loc
# katz katz+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom+Proper=True
# , ,+PUNCT
# iik ilk+ADJ
# olErEK ol+VERB+Polarity=Pos+Derivation=Ger
# ahşap ahşap+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# , ,+PUNCT
# sonralArI sonra+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Bare
# alüminyum alüminyum+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# levhalArDAn levha+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Abl
# kesIp kes+VERB+Polarity=Pos+Derivation=After
# şekillAnDIrDIKI şekil+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Acq+Derivation=Cau+Polarity=Pos+Derivation=PastPart+Possessive=P3sg
# biçimlArI biçim+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Acc
# boyayErEK boya+VERB+Polarity=Pos+Derivation=Ger
# yapDIKI yap+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg
# ve ve+CONJ+ConjunctionType=Coor
# cutouts cutouts+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# adInI ad+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Acc
# verDIKI ver+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg
# tekniğI teknik+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Acc
# gelişDIrDI geliş+VERB+Derivation=Cau+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# aynı aynı+ADJ
# gün gün+NOUN+Temporal=True+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# , ,+PUNCT
# hitler hitler+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# adInA ad+ADP^CBare+Possessive=P3sg+Case=Dat
# general general+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# alfred alfred+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# jodl jodl+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# tarafInDAn taraf+ADP^CBare+Possessive=P3sg+Case=Abl
# imzalAnAn imza+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Make+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# bir bir+DET^Ind
# emirDA emir+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# , ,+PUNCT
# kentIn kent+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Gen
# can can+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# ve ve+CONJ+ConjunctionType=Coor
# mal mal+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# güvenlIKI güven+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Ness+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# , ,+PUNCT
# özel özel+ADJ
# mülkiyet mülkiyet+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# haklArInIn hak+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Gen
# korunmAsI koru+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# gibi gibi+ADP^CBare+Possessive=Pnon+Case=Bare
# koşullArlA koşul+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Ins
# teslim teslim+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# olmA ol+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# taleplArInIn talep+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Gen
# kabul kabul+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# edIlmAyAcAKI et+VERB+Derivation=Pass+Polarity=Neg+Derivation=FutNom+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# bilDIrIlDI bil+VERB+Derivation=Cau+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# penaltı[Y]I penaltı+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Acc
# kullanmAyA kullan+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# gelIrken gel+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg+Derivation=While
# de de+PRT
# birkaç birkaç+DET^Ind
# kez kez+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# durDI dur+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# penaltı penaltı+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# atIşlArINDA at+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3pl+Possessive=P3sg+Case=Loc
# kaçIrDIKI kaç+VERB+Derivation=Cau+Polarity=Pos+Derivation=PastPart+Possessive=P3sg
# gol gol+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom
# , ,+PUNCT
# chelsea'yA chelsea+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Dat+Proper=True
# şampiyonlAr şampiyon+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Bare+Proper=True
# ligI lig+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Proper=True
# kupasI'nI kupa+NOUN+PersonNumber=A3sg+Possessive=P3sg+Apostrophe=True+Case=Acc+Proper=True
# kazanmA kazan+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# fırsatI fırsat+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# verDI ver+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# ama ama+CONJ+ConjunctionType=Coor
# john john+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# terry'nIn terry+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Gen+Proper=True
# de de+PRT
# penaltı penaltı+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# kaçIrmAsIYlA kaç+VERB+Derivation=Cau+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Ins
# , ,+PUNCT
# manchester manchester+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# united united+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom+Proper=True
# penaltılArI penaltı+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Acc
# 6 6+NUM
# \- -+PUNCT
# 5 5+NUM
# kazanDI kazan+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# bir bir+NUM
# defasINDA defa+ADP^CNum+Possessive=P3sg+Case=Loc
# savaşIrken savaş+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg+Derivation=While
# o o+DET^Dem
# sahne[Y]I sahne+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Acc
# çizAbilmAk çiz+VERB+Derivation=Able+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# için için+ADP^CBare+Possessive=Pnon+Case=Bare
# rakibInI rakip+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Acc
# durdIrDIKI dur+VERB+Derivation=Cau+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# bile bile+PRT
# söylenmAkteDIr söyle+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# günlük günlük+ADJ
# yaşamInIzDA yaşam+NOUN+PersonNumber=A3sg+Possessive=P2pl+Case=Loc
# , ,+PUNCT
# hem hem+CONJ+ConjunctionType=Par
# geleceğInIzI gelecek+NOUN+PersonNumber=A3sg+Possessive=P2pl+Case=Acc
# öğrenmAkDA öğren+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# , ,+PUNCT
# hem hem+CONJ+ConjunctionType=Par
# kendinizI kendi+PRON+PersonNumber=A3sg+Possessive=P2sg+Case=Acc
# keşfetmAkDA keşfet+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# , ,+PUNCT
# hem hem+CONJ+ConjunctionType=Par
# de de+PRT
# atAcAKInIz at+VERB+Polarity=Pos+Derivation=FutPart+Possessive=P2pl
# en en+ADV
# iyi iyi+ADJ
# adımI adım+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Acc
# anlamAkDA anla+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# kullanAbilAcAKInIz kullan+VERB+Derivation=Able+Polarity=Pos+Derivation=FutPart+Possessive=P2pl
# harikulâde harikulâde+ADJ
# bir bir+DET^Ind
# kılavuz kılavuz+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# türk türk+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# ordulArInIn ordu+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Gen
# lübnan lübnan+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# ve ve+CONJ+ConjunctionType=Coor
# suriye'[Y]I suriye+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Acc+Proper=True
# boşalTmAsI boşal+VERB+Derivation=Cau+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# üzerInA üzer+ADP^CBare+Possessive=P3sg+Case=Dat
# 4 4+NUM
# mart mart+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# 1918'DA 1918+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# i̇stanbul'A istanbul+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Dat+Proper=True
# dönDI dön+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# her her+DET^Def
# ne ne+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# kadar kadar+ADP^CBare+Possessive=Pnon+Case=Bare
# araştırmAlAr araştır+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3pl+Possessive=Pnon+Case=Nom
# devam devam+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# etsA et+VERB+Polarity=Pos+TenseAspectMood=Desr+Copula=PresCop+PersonNumber=V3pl
# de de+PRT
# , ,+PUNCT
# güncel güncel+ADJ
# araştırmAlAr araştır+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3pl+Possessive=Pnon+Case=Nom
# durumIn durum+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Gen
# bu bu+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# olmADIKInI ol+VERB+Polarity=Neg+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc
# göstermIşDIr göster+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3pl
# \. .+PUNCT
# elbet elbet+ADV
# bach bach+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom+Proper=True
# da da+PRT
# öyle öyle+ADV
# yapDI yap+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# mö mö+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# 2000'lI 2000+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With
# yıllArDA yıl+NOUN+Temporal=True+PersonNumber=A3pl+Possessive=Pnon+Case=Loc
# buraDA bura+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# hititlAr'A hitit+NOUN+PersonNumber=A3pl+Apostrophe=True+Possessive=Pnon+Case=Dat+Proper=True
# bağlI bağ+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With
# kadu kadu+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# beylIKI'nIn bey+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True+Derivation=Ness+Possessive=P3sg+Apostrophe=True+Case=Gen+Proper=True
# kurIlDIKI kur+VERB+Derivation=Pass+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# bilInmAkteDIr bil+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg
# \( (+PUNCT
# kadu kadu+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom+Proper=True
# , ,+PUNCT
# hititCA hitit+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True+Derivation=Lang+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# körfez körfez+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# anlamInA anlam+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Dat
# gelmAkteDIr gel+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# \) )+PUNCT
# \. .+PUNCT
# bu bu+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# sayeDA saye+ADP^CBare+Possessive=Pnon+Case=Loc
# anadolu'DA anadolu+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Loc+Proper=True
# alevî alevî+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# anlayIşInI anla+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Acc
# daha daha+ADV
# da da+PRT
# artırDI artır+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# kaptan kaptan+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# flint'In flint+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Gen+Proper=True
# eski eski+ADJ
# serdümenI serdümen+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# olAn ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# silver'In silver+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Gen+Proper=True
# eski eski+ADJ
# tayfasI tayfa+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# üzerINDA üzer+ADP^CBare+Possessive=P3sg+Case=Loc
# çok çok+ADV
# büyük büyük+ADJ
# etkisI etki+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# varDIr var+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# bu bu+DET^Dem
# boşlIK boş+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Ness+PersonNumber=A3sg+Possessive=Pnon+Case=Nom
# , ,+PUNCT
# sivas sivas+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# ve ve+CONJ+ConjunctionType=Coor
# kayseri'DA kayseri+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Loc+Proper=True
# yaylaYAn yayla+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# dulkadiroğulları dulkadiroğulları+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Bare+Proper=True
# türkmenlArInA türkmen+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Dat+Proper=True
# yaraDI yara+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# 15 15+NUM
# yaşINDAyken yaş+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Loc+Derivation=While
# , ,+PUNCT
# 1990 1990+NUM
# yılINDA yıl+NOUN+Temporal=True+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# , ,+PUNCT
# kariyerInI kariyer+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Acc
# ticaret ticaret+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# sektörINDA sektör+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# çizmAyA çiz+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# karar karar+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# verDIKI ver+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# için için+ADP^CBare+Possessive=Pnon+Case=Bare
# aile aile+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# dostlArI dost+NOUN+PersonNumber=A3sg+Possessive=P3pl+Case=Bare
# olAn ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# `` ``+PUNCT
# brian brian+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# muldoon muldoon+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# '' ''+PUNCT
# ın ın+X+Case=Gen+Proper=True
# yanINDA yan+ADP^CGen+Possessive=P3sg+Case=Loc
# , ,+PUNCT
# mobilyaCI mobilya+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Agt+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# atölyesINDA atölye+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# yarı yarı+ADJ
# zamanlI zaman+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With
# , ,+PUNCT
# çırak çırak+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# olErEK ol+VERB+Polarity=Pos+Derivation=Ger
# çalışmAyA çalış+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# başlamIşDIr başla+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# antik antik+ADJ
# yahudi yahudi+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# tarihCI tarih+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Agt+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# flavius flavius+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# josephus'In josephus+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Gen+Proper=True
# anlatımIYlA anlatım+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Ins
# ; ;+PUNCT
# `` ``+PUNCT
# önceDAn önce+NOUN+Temporal=True+PersonNumber=A3sg+Possessive=Pnon+Case=Abl
# bunA bu+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# niyetI niyet+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# olAn ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# kral kral+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom
# , ,+PUNCT
# onlarA onlar+PRON+PersonNumber=A3pl+Possessive=Pnon+Case=Dat
# boyun boyun+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# eğDI eğ+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# ve ve+CONJ+ConjunctionType=Coor
# büyük büyük+ADJ
# bir bir+DET^Ind
# orduYlA ordu+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Ins
# yahudilArA yahudi+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Dat+Proper=True
# hücum hücum+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# etDI et+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# , ,+PUNCT
# şehirlArInI şehir+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Acc
# zorlA zor+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Ins
# alDI al+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# ve ve+CONJ+ConjunctionType=Coor
# ptolemi ptolemi+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# yanlısI yanlı+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# çok çok+DET^Ind
# sayıDAki sayı+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc+Derivation=Rel
# insanI insan+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Acc
# katletDI katlet+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# , ,+PUNCT
# ve ve+CONJ+ConjunctionType=Coor
# etrafI etraf+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Acc
# talan talan+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# etmAk et+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# için için+ADP^CBare+Possessive=Pnon+Case=Bare
# askerlArInI asker+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Acc
# gönderDI gönder+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# buraDA bura+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# uzun uzun+ADV
# yaşamA yaşa+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# dileğI dilek+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# sembolik sembolik+ADJ
# olIp ol+VERB+Polarity=Pos+Derivation=After
# , ,+PUNCT
# krallIKI kral+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Ness+PersonNumber=A3sg+Possessive=Pnon+Case=Acc
# kastetmAkteDIr kastet+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# bu bu+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# yüzDAn yüz+ADP^CBare+Possessive=Pnon+Case=Abl
# hem hem+CONJ+ConjunctionType=Par
# yeni yeni+ADJ
# hem hem+CONJ+ConjunctionType=Par
# de de+PRT
# güvenlI güven+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With
# olmAlIDIr ol+VERB+Polarity=Pos+TenseAspectMood=Nec+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# kendilArInDAn kendi+PRON+PersonNumber=A3sg+Possessive=P3pl+Case=Abl
# ilîm ilim+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# öğrenDI öğren+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# bu bu+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Nom
# , ,+PUNCT
# rath'A rath+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Dat+Proper=True
# göre göre+ADP^CDat+Possessive=Pnon+Case=Bare
# tanrıçanIn tanrıça+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Gen
# gücInI güç+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Acc
# göstermAkteDIr göster+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# 54 54+NUM
# \- -+PUNCT
# 68 68+NUM
# yıllArI yıl+NOUN+Temporal=True+PersonNumber=A3sg+Possessive=P3pl+Case=Bare
# arasINDA ara+ADP^CBare+Possessive=P3sg+Case=Loc
# i̇mparatorlIKI imparator+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Ness+PersonNumber=A3sg+Possessive=Pnon+Case=Acc
# yönetAn yönet+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# nero nero+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom+Proper=True
# , ,+PUNCT
# saltanatI saltanat+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# boyunca boyunca+ADP^CBare+Possessive=Pnon+Case=Bare
# dikkatInI dikkat+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Acc
# daha daha+ADV
# çok çok+ADV
# diplomasi diplomasi+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# , ,+PUNCT
# ticaret ticaret+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# ve ve+CONJ+ConjunctionType=Coor
# imparatorlIKIn imparator+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Ness+PersonNumber=A3sg+Possessive=Pnon+Case=Gen
# kültürel kültürel+ADJ
# sermayesInIn sermaye+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Gen
# artDIrIlmAsI art+VERB+Derivation=Cau+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# üzerInA üzer+ADP^CBare+Possessive=P3sg+Case=Dat
# yönelTmIşDIr yönel+VERB+Derivation=Cau+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# arıCIlIK arı+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Agt+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Ness+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# : :+PUNCT
# ilçeDA ilçe+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# 500 500+NUM
# adet adet+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# yerlI yer+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=From
# , ,+PUNCT
# 1500 1500+NUM
# adet adet+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# fenni fenni+ADJ
# kovan kovan+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom
# bulunmAkta bulun+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=PresCop+PersonNumber=V3pl
# ve ve+CONJ+ConjunctionType=Coor
# yıllIk yıl+NOUN+Temporal=True+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=For
# yaklaşık yaklaşık+ADJ
# 15000 15000+NUM
# kg\. kg.+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# bal bal+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom
# elDA el+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# edIlmAkteDIr et+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# bunDAn bu+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Abl
# sonra sonra+ADP^CAbl+Possessive=Pnon+Case=Bare
# türk türk+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# komutanlArInIn komutan+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Gen
# kendi kendi+ADJ
# aralArINDA ara+NOUN+PersonNumber=A3sg+Possessive=P3pl+Case=Loc
# baş baş+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# gösterAn göster+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# rekabetlAr rekabet+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Bare
# , ,+PUNCT
# diğer diğer+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# yanDAn yan+ADP^CBare+Possessive=Pnon+Case=Abl
# emirü'l emirü'l+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# \- -+PUNCT
# ümeralIK ümera+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True+Derivation=Ness+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# üzerInA üzer+ADP^CBare+Possessive=P3sg+Case=Dat
# şii şii+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# deylemlArlA deylem+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Ins+Proper=True
# olAn ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# çekmAlAr çek+VERB+Derivation=Rcp+Polarity=Pos+Derivation=Nonf+PersonNumber=A3pl+Possessive=Pnon+Case=Bare
# , ,+PUNCT
# halifelArIn halife+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Gen
# de de+PRT
# bu bu+DET^Dem
# rekabet rekabet+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# ve ve+CONJ+ConjunctionType=Coor
# çekmAlArI çek+VERB+Derivation=Rcp+Polarity=Pos+Derivation=Nonf+PersonNumber=A3pl+Possessive=Pnon+Case=Acc
# körüklAmAk körük+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Make+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# için için+ADP^CBare+Possessive=Pnon+Case=Bare
# entrikalArA entrika+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Dat
# girmAlArI gir+VERB+Derivation=Rcp+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3pl+Case=Nom
# , ,+PUNCT
# abbasî abbasî+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# i̇mparatorlIKI'nIn imparator+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True+Derivation=Ness+PersonNumber=A3sg+Possessive=P3sg+Apostrophe=True+Case=Gen+Proper=True
# itibarInI itibar+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Acc
# iyicA iyi+ADJ+Derivation=Ly
# sarsmAğA sars+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# başlamIş başla+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=PresCop+PersonNumber=V3pl
# ve ve+CONJ+ConjunctionType=Coor
# merkez merkez+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# bağdat'A bağdat+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Dat+Proper=True
# bağlI bağ+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With
# valilAr vali+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Nom
# de de+PRT
# , ,+PUNCT
# bu bu+DET^Dem
# karışıklIKlArDAn karışık+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Ness+PersonNumber=A3pl+Possessive=Pnon+Case=Abl
# yararlAnErEK yarar+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Acq+Polarity=Pos+Derivation=Ger
# yer yer+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# yer yer+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# bağımsIzlIKlArINI bağım+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Wout+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Ness+PersonNumber=A3sg+Possessive=P3pl+Case=Acc
# ilan ilan+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# etmAk et+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# yolInA yol+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Dat
# gitmIşlArDI git+VERB+Polarity=Pos+TenseAspectMood=Nar+PersonNumber=V3pl+Copula=PastCop
# \. .+PUNCT
# bo bo+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# mccalebb mccalebb+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom+Proper=True
# abd abd+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# kökenlI köken+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With
# bir bir+DET^Ind
# oyunCI oyun+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Agt+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# olmAsInA ol+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Dat
# rağmen rağmen+ADP^CDat+Possessive=Pnon+Case=Bare
# 2010 2010+NUM
# yılINDA yıl+NOUN+Temporal=True+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# makedon makedon+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# pasaportI pasaport+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# alDI al+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# ve ve+CONJ+ConjunctionType=Coor
# makedonya makedonya+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# millî millî+ADJ+Proper=True
# basketbol basketbol+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# takımI takım+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Proper=True
# için için+ADP^CBare+Possessive=Pnon+Case=Bare
# oynamAyA oyna+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# başlaDI başla+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# o o+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Nom
# memphis memphis+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# grizzlies grizzlies+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# , ,+PUNCT
# cleveland cleveland+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# cavaliers cavaliers+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# ve ve+CONJ+ConjunctionType=Coor
# chicago chicago+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# bulls bulls+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# ile ile+ADP^CBare+Possessive=Pnon+Case=Bare
# oynanAn oyna+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# 3 3+NUM
# maçDA maç+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# toplam toplam+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# 37 37+NUM
# asist asist+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# yapmA[Y]I yap+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Acc
# başarDI başar+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# ve ve+CONJ+ConjunctionType=Coor
# sadece sadece+ADJ
# 3 3+NUM
# top top+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# kaybı kayıp+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# yapDI yap+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# sulh sulh+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# ceza ceza+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# mahkemesI'nIn mahkeme+NOUN+PersonNumber=A3sg+Possessive=P3sg+Apostrophe=True+Case=Gen+Proper=True
# 17 17+NUM
# ocak ocak+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# 2008 2008+NUM
# tarihINDA tarih+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# alDIKI al+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg
# 2008/55 2008/55+NUM
# nolI no+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With
# kararIYlA karar+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Ins
# engellAnmIşDIr engel+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Make+Derivation=Pass+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# çoğu çoğu+DET^Ind
# protestolArlA protesto+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Ins
# 2001 2001+NUM
# seçimlArInI seçim+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Acc
# boykot boykot+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# etDI et+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# i̇nziva inziva+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# kuralInA kural+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Dat
# dayanAn dayan+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# manastır manastır+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# yaşamI yaşam+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# gereğInce gerek+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Derivation=By
# halkA halk+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# açık açık+ADJ
# olmAYAn ol+VERB+Polarity=Neg+Derivation=PresPart+Possessive=Pnon
# bu bu+DET^Dem
# hücrelArDAki hücre+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Loc+Derivation=Rel
# resimlAr resim+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Nom
# , ,+PUNCT
# ressam ressam+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# \- -+PUNCT
# keşişIn keşiş+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Gen
# öbür öbür+DET^Ind
# keşişlArI keşiş+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Acc
# tefekkür tefekkür+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# ve ve+CONJ+ConjunctionType=Coor
# dua dua+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# etmAyA et+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# yönelTAn yönel+VERB+Derivation=Cau+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# arınmIş arın+VERB+Polarity=Pos+Derivation=PerPart+Possessive=Pnon
# figürlAr figür+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Bare
# yaratmAkDAn yarat+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Abl
# duyDIKI duy+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg
# gizlI giz+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With
# mutlulIKI mutlu+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Ness+PersonNumber=A3sg+Possessive=Pnon+Case=Acc
# ortayA orta+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# koymAktaDIr koy+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3pl
# \. .+PUNCT
# ahit ahit+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# i̇branICAsINDA ibrani+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True+Derivation=Lang+PersonNumber=A3sg+Possessive=P3sg+Case=Loc+Proper=True
# bir bir+DET^Ind
# seri seri+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# `` ``+PUNCT
# vurgusAl vurgu+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Rtd
# '' ''+PUNCT
# sessIz ses+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Wout
# harflAr harf+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Nom
# bulunIr bulun+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl
# ve ve+CONJ+ConjunctionType=Coor
# bu bu+DET^Dem
# harflArIn harf+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Gen
# söylenIş söyle+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# şekli şekil+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# tartışmA tartış+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# konusIdIr konu+VERB+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Copula=GenCop+PersonNumber=V3sg
# ; ;+PUNCT
# muhtemelen muhtemelen+ADV
# ejektif ejektif+ADJ
# veya veya+CONJ+ConjunctionType=Coor
# faringealDIr faringeal+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# nato'CIlAr nato+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True+Derivation=Agt+PersonNumber=A3pl+Possessive=Pnon+Case=Nom
# ' '+PUNCT
# misillAmA misil+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Make+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# harekatI harekat+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# ' '+PUNCT
# başlaTErEK başla+VERB+Derivation=Cau+Polarity=Pos+Derivation=Ger
# ilk ilk+ADJ
# fırsatDA fırsat+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# radovan radovan+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# karaciç'I karaciç+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Acc+Proper=True
# öldürmAk öl+VERB+Derivation=Cau+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# amacInI amaç+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Acc
# gütmIşlArDIr güt+VERB+Polarity=Pos+TenseAspectMood=Nar+PersonNumber=V3pl+Copula=GenCop
# \. .+PUNCT
# ermenistan ermenistan+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# cumhuriyetI'nIn cumhuriyet+NOUN+PersonNumber=A3sg+Possessive=P3sg+Apostrophe=True+Case=Gen+Proper=True
# resmî resmî+ADJ
# dilI dil+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# doğu doğu+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# ermeniCAsIdIr ermeni+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True+Derivation=Lang+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# mardakert mardakert+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# ve ve+CONJ+ConjunctionType=Coor
# martuni martuni+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# taarruzlArI taarruz+NOUN+PersonNumber=A3sg+Possessive=P3pl+Case=Bare
# topIn top+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Gen
# zeminDA zemin+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# gösterDIKI göster+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg
# farklI fark+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With
# tepkilAr tepki+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Bare
# , ,+PUNCT
# koşIcIlArIn koş+VERB+Polarity=Pos+Derivation=Inh+PersonNumber=A3pl+Possessive=Pnon+Case=Gen
# düşErEK düş+VERB+Polarity=Pos+Derivation=Ger
# sakatlAnmAsI sakat+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Make+Derivation=Rfx+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# gibi gibi+ADP^CBare+Possessive=Pnon+Case=Bare
# olaylArIn olay+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Gen
# önInA ön+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Dat
# geçmAsI geç+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# için için+ADP^CBare+Possessive=Pnon+Case=Bare
# yağmurlI yağmur+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With
# havalArDA hava+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Loc
# maçlArA maç+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Dat
# ara ara+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom
# verIlebIlIr ver+VERB+Derivation=Pass+Derivation=Able+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg
# ve ve+CONJ+ConjunctionType=Coor
# saha saha+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom
# yağmurDAn yağmur+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Abl
# korunIr koru+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# logaritmik logaritmik+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# ve ve+CONJ+ConjunctionType=Coor
# üstel üstel+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# ...
# 3\. 3+NUM+NumberType=Ord
# binyılIn binyıl+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Gen
# ikinci iki+NUM+NumberType=Ord
# yarısINDA yarı+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# batı batı+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# anadolu'yA anadolu+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Dat+Proper=True
# kadar kadar+ADP^CDat+Possessive=Pnon+Case=Bare
# yayIlmA yay+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# göstermIşDIr göster+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3pl
# \. .+PUNCT
# dört dört+NUM
# tekerlek tekerlek+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# disk disk+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# frenlAr fren+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Nom
# , ,+PUNCT
# önDA ön+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# 300 300+NUM
# mm mm+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# \( (+PUNCT
# 11\.8 11.8+NUM
# inç inç+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# \) )+PUNCT
# ve ve+CONJ+ConjunctionType=Coor
# arkaDA arka+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# 279 279+NUM
# mm mm+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# \( (+PUNCT
# 11 11+NUM
# inç inç+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# \) )+PUNCT
# olmAk ol+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# üzerA üzer+ADP^CBare+Possessive=Pnon+Case=Dat
# monte monte+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# edIlmIşDIr et+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3pl
# \. .+PUNCT
# metal metal+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# davulCIlArInIn davul+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Agt+PersonNumber=A3pl+Possessive=P3sg+Case=Gen
# karakteristik karakteristik+ADJ
# tekniğI teknik+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# zil zil+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# boğmADIr boğ+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# i̇nsanlArIn insan+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Gen
# , ,+PUNCT
# kendilArInIn kendi+PRON+PersonNumber=A3sg+Possessive=P3pl+Case=Gen
# nasıl nasıl+ADV
# görInDIKlerINI gör+VERB+Derivation=Rfx+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3pl+Case=Acc
# işitmAkDAn işit+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Abl
# hoşlAnmADIKlArINI hoş+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Acq+Polarity=Neg+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3pl+Case=Acc
# farkedAn farket+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# sai sai+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom+Proper=True
# , ,+PUNCT
# görDIKlArInIn gör+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3pl+Possessive=P3sg+Case=Gen
# tersInI ters+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Acc
# söylemAyA söyle+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# başlar başla+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg
# ; ;+PUNCT
# örneğin örneğin+CONJ+ConjunctionType=Adv
# ino ıno+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# yamanaka'[Y]I yamanaka+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Acc+Proper=True
# `` ``+PUNCT
# güzel güzel+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# '' ''+PUNCT
# diye diye+ADP^CBare+Possessive=Pnon+Case=Bare
# çağırIr çağır+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# kara kara+ADJ
# yusuf yusuf+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom+Proper=True
# bu bu+DET^Dem
# savaşDA savaş+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# büyük büyük+ADJ
# ganimet ganimet+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# elA el+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# geçirDI geçir+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# tower tower+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# slave slave+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# \( (+PUNCT
# kule kule+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# kölesI köle+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# \) )+PUNCT
# : :+PUNCT
# gor'In gor+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Gen+Proper=True
# her her+DET
# hangi hangi+X
# bir bir+DET^Ind
# şehriNDA şehir+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# , ,+PUNCT
# silindir silindir+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# mimariyA mimari+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# sahip sahip+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=PresCop+PersonNumber=V3sg
# binalArINDA bina+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Loc
# hizmet hizmet+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# edAn et+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# köle köle+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# kızlArDIr kız+VERB+PersonNumber=A3pl+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# lance lance+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# tarrance tarrance+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# , ,+PUNCT
# jr\. jr.+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom+Proper=True
# , ,+PUNCT
# çıkIş çık+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# anketlArInIn anket+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Gen
# başarısIz başarı+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Wout
# olmA ol+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# nedenInI neden+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Acc
# bradley'In bradley+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Gen+Proper=True
# kullanIlAn kullan+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# oylAr oy+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Nom
# dikkatA dikkat+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# alInDIKINDA al+VERB+Derivation=Pass+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# kazanmAsInA kazan+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Dat
# karşın karşın+ADP^CDat+Possessive=Pnon+Case=Bare
# tüm tüm+DET^Def
# oylAr oy+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Nom
# dikkatA dikkat+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# alInDIKINDA al+VERB+Derivation=Pass+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# kaybetmAsInA kaybet+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Dat
# bağlAmIşDIr bağ+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Make+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# barış barış+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# manço manço+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# ve ve+CONJ+ConjunctionType=Coor
# les les+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# mistigris mistigris+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# ancak ancak+CONJ+ConjunctionType=Adv
# tötonlAr töton+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Nom+Proper=True
# , ,+PUNCT
# ortadoğu'DA ortadoğu+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Loc+Proper=True
# hiçbir hiçbir+DET^Ind
# zaman zaman+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# siyasi siyasi+ADJ
# , ,+PUNCT
# askeri askeri+ADJ
# ve ve+CONJ+ConjunctionType=Coor
# lojistik lojistik+ADJ
# açılArDAn açı+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Abl
# tapınakCIlAr tapınak+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True+Derivation=Agt+PersonNumber=A3pl+Possessive=Pnon+Case=Bare+Proper=True
# ve ve+CONJ+ConjunctionType=Coor
# hospitallAr hospital+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Bare+Proper=True
# kadar kadar+ADP^CBare+Possessive=Pnon+Case=Bare
# etkin etkin+ADJ
# olamADIlAr ol+VERB+Derivation=Able+Polarity=Neg+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl
# \. .+PUNCT
# amida amida+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# dualArINDAkI dua+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Loc+Derivation=Rel
# `` ``+PUNCT
# i̇srailoğullArInIn israiloğlu+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Gen+Proper=True
# yakımlIk yakım+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=For
# sunulArI sunu+NOUN+PersonNumber=A3sg+Possessive=P3pl+Case=Bare
# '' ''+PUNCT
# ve ve+CONJ+ConjunctionType=Coor
# `` ``+PUNCT
# yehuda'nIn yehuda+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Gen+Proper=True
# ve ve+CONJ+ConjunctionType=Coor
# kudüs'In kudüs+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Gen+Proper=True
# tahıl tahıl+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# sunulArI sunu+NOUN+PersonNumber=A3sg+Possessive=P3pl+Case=Bare
# '' ''+PUNCT
# ile ile+ADP^CBare+Possessive=Pnon+Case=Bare
# ilgilI ilgi+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With
# kısımlAr kısım+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Nom
# çıkarIlmIşDIr çıkar+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3pl
# \. .+PUNCT
# kedinIn kedi+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Gen
# boyI boy+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# 1,62 1,62+NUM
# \-\- --+PUNCT
# 1,83 1,83+NUM
# metre metre+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# arasINDA ara+ADP^CBare+Possessive=P3sg+Case=Loc
# değişIr değiş+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg
# ve ve+CONJ+ConjunctionType=Coor
# bu bu+DET^Dem
# boyA boy+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Dat
# kuyruk kuyruk+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom
# 75 75+NUM
# santimetre santimetre+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# daha daha+ADV
# eklAr ek+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Make+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg
# \. .+PUNCT
# sonINDA son+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# rusya'nIn rusya+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Gen+Proper=True
# eflak eflak+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# ve ve+CONJ+ConjunctionType=Coor
# boğdan'A boğdan+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Dat+Proper=True
# girmAsIYlA gir+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Ins
# osmanlılAr osmanlı+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Nom+Proper=True
# rusya'yA rusya+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Dat+Proper=True
# savaş savaş+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# açDIlAr aç+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl
# \. .+PUNCT
# çene çene+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# boşlIKI boş+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Ness+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# , ,+PUNCT
# ince ince+ADJ
# uzun uzun+ADJ
# dilIn dil+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Gen
# dışarı dışarı+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# çıkAbIlAcAKI çık+VERB+Derivation=Able+Polarity=Pos+Derivation=FutNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# kadar kadar+ADP^CBare+Possessive=Pnon+Case=Bare
# genişlIKDA geniş+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Ness+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# bir bir+DET^Ind
# boşlIKDAn boş+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Ness+PersonNumber=A3sg+Possessive=Pnon+Case=Abl
# ibaretDIr ibaret+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# bazı bazı+DET^Ind
# insanlAr insan+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Nom
# şamaş'I şamaş+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Acc+Proper=True
# önce önce+ADV+Temporal=True
# yakIp yak+VERB+Polarity=Pos+Derivation=After
# sonra sonra+ADV
# diğerlArINI diğer+PRON+PersonNumber=A3sg+Possessive=P3pl+Case=Acc
# yakmAk yak+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# için için+ADP^CBare+Possessive=Pnon+Case=Bare
# kullanIr kullan+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl
# \. .+PUNCT
# kanada'yA kanada+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Dat+Proper=True
# göçmen göçmen+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# olErEK ol+VERB+Polarity=Pos+Derivation=Ger
# gidIşlA git+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Ins
# birlikte birlikte+ADP^CIns+Possessive=Pnon+Case=Bare
# pek pek+DET
# çok çok+DET^Ind
# aile aile+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Nom
# kanada'yA kanada+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Dat+Proper=True
# işCI iş+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Agt+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# olErEK ol+VERB+Polarity=Pos+Derivation=Ger
# yerleşmIşDIr yerleş+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3pl
# \. .+PUNCT
# bu bu+DET^Dem
# dönemDA dönem+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# , ,+PUNCT
# avrupa'DAki avrupa+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Loc+Proper=True+Derivation=Rel
# halklAr halk+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Nom
# zamanlA zaman+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Ins
# yulaf yulaf+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# , ,+PUNCT
# çavdar çavdar+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# ve ve+CONJ+ConjunctionType=Coor
# arpa arpa+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# ekmA[Y]I ek+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Acc
# öğrenDI öğren+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl
# \. .+PUNCT
# şu şu+DET^Dem
# anDA an+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc
# yunanistan yunanistan+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# basketbol basketbol+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# ligI'NDA lig+NOUN+PersonNumber=A3sg+Possessive=P3sg+Apostrophe=True+Case=Loc+Proper=True
# mücadele mücadele+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# edAn et+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# olympiakos'DA olympiakos+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Loc+Proper=True
# forma forma+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# giymAkteDIr giy+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg
# \. .+PUNCT
# güzellAmAlAr güzel+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Make+Polarity=Pos+Derivation=Nonf+PersonNumber=A3pl+Possessive=Pnon+Case=Nom
# halk halk+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# edebiyatINDA edebiyat+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# en en+ADV
# çok çok+ADV
# tercih tercih+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# edIlAn et+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon
# türlArDAnDIr tür+VERB+PersonNumber=A3pl+Possessive=Pnon+Case=Abl+Copula=GenCop+PersonNumber=V3pl
# \. .+PUNCT
# oldIkCA ol+VERB+Polarity=Pos+Derivation=As
# zor zor+ADJ
# ve ve+CONJ+ConjunctionType=Coor
# karmaşık karmaşık+ADJ
# gitar gitar+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# partisyonlArI partisyon+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Bare
# , ,+PUNCT
# marty marty+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# friedman'In friedman+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Gen+Proper=True
# sololArI solo+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Bare
# ve ve+CONJ+ConjunctionType=Coor
# nick nick+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True
# menza'nIn menza+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Gen+Proper=True
# davul davul+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# tekniğI teknik+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Nom
# de de+PRT
# , ,+PUNCT
# albümIn albüm+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Gen
# başarısINDA başarı+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Loc
# önemlI önem+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With
# pay pay+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare
# sahibI sahip+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare
# olmIşDIr ol+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3pl
# \. .+PUNCT

# %%
pos_wiki_counts, feat_wiki_count = get_tag_counts(wiki_pairs)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-0ca09eca2ec0> in <module>
# ----> 1 pos_wiki_counts, feat_wiki_count = get_tag_counts(wiki_pairs)
#
# <ipython-input-8-535314640eab> in get_tag_counts(pairs)
#       5         morphs = [token[1] for token in pairs[:-1]]
#       6
# ----> 7     pos = [token.split(" ")[1] for token in morphs if token != "?"]
#       8     feats = [token.split(" ")[2:] for token in morphs]
#       9     feat_extend = []
#
# <ipython-input-8-535314640eab> in <listcomp>(.0)
#       5         morphs = [token[1] for token in pairs[:-1]]
#       6
# ----> 7     pos = [token.split(" ")[1] for token in morphs if token != "?"]
#       8     feats = [token.split(" ")[2:] for token in morphs]
#       9     feat_extend = []
#
# IndexError: list index out of range

# %%
pos_wiki_counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-fd93009fdf56> in <module>
# ----> 1 pos_wiki_counts
#
# NameError: name 'pos_wiki_counts' is not defined

# %%
feat_wiki_count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-88f403077b2e> in <module>
# ----> 1 feat_wiki_count
#
# NameError: name 'feat_wiki_count' is not defined

# %%
def get_indices(pairs, POS=False ,feat=False):
    try:
        morphs = [token[1] for token in pairs]
    except:
        morphs = [token[1] for token in pairs[:-1]]

    if POS:
        pos = [token.split("+")[1] for token in morphs if token != "?"]
        pos_indices = pd.Series(pos)
        pos_indices = pos_indices[pos_indices == POS].index
        return pos_indices

    if feat:
        feats = [token.split("+")[2:] for token in morphs]
        feat_extend = []
        for feat in feats:
            feat_extend.extend(feat)

    return pd.Series(pos).value_counts(), pd.Series(feat_extend).value_counts()

# %%
get_indices(wiki_pairs,POS="ADJ")
# Out:
# Int64Index([   24,    49,    53,    55,    66,    68,    89,   100,   120,
#               139,
#             ...
#             39711, 39715, 39777, 39779, 39781, 39787, 39841, 39842, 39911,
#             39913],
#            dtype='int64', length=1929)

# %%
wiki_adj = [wiki_pairs[i] for i in get_indices(wiki_pairs, POS='VERB')]

# %%
wiki_adj
# Out:
# [['katılDIKI', 'katıl+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['kaybetDIlAr',
#   'kaybet+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl'],
#  ['gelInDIKINDA',
#   'gel+VERB+Derivation=Pass+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Loc'],
#  ['besleyAbilAcAkDIr',
#   'besle+VERB+Derivation=Able+Polarity=Pos+TenseAspectMood=Fut+Copula=GenCop+PersonNumber=V3sg'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['katılDIKInI',
#   'katıl+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['etDI',
#   'et+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['ölAnlAr',
#   'öl+VERB+Polarity=Pos+Derivation=PresNom+PersonNumber=A3pl+Possessive=Pnon+Case=Bare'],
#  ['dikIlmIşDIr',
#   'dik+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3pl'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['gelDIKI',
#   'gel+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['edIlAcAKInA',
#   'et+VERB+Derivation=Pass+Polarity=Pos+Derivation=FutNom+PersonNumber=A3sg+Possessive=P3sg+Case=Dat'],
#  ['inansA',
#   'inan+VERB+Polarity=Pos+TenseAspectMood=Desr+Copula=PresCop+PersonNumber=V3pl'],
#  ['inanAn',
#   'inan+VERB+Polarity=Pos+Derivation=PresNom+PersonNumber=A3sg+Possessive=Pnon+Case=Nom'],
#  ['edIp', 'et+VERB+Polarity=Pos+Derivation=After'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['edIlmAsI',
#   'et+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Nom'],
#  ['gerekDIKInI',
#   'gerek+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['savunmAktaDIr',
#   'savun+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3pl'],
#  ['olmAnIn',
#   'ol+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Gen'],
#  ['korunmA',
#   'koru+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['yaklaşmIşlAr',
#   'yaklaş+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=PresCop+PersonNumber=V3pl'],
#  ['bulunDIKI', 'bulun+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['edIr',
#   'et+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['oluşIr',
#   'oluş+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['yapIlAn',
#   'yap+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['başlamAdan', 'başla+VERB+Polarity=Neg+Derivation=Ger'],
#  ['toparlamAsInA',
#   'toparla+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Dat'],
#  ['sağlamAdan', 'sağla+VERB+Polarity=Neg+Derivation=Ger'],
#  ['başlanmAsInA',
#   'başla+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Dat'],
#  ['girmIş',
#   'gir+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=PresCop+PersonNumber=V3sg'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['gidIlmAsInA',
#   'git+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Dat'],
#  ['verIlDI',
#   'ver+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['olAcAKInIn',
#   'ol+VERB+Polarity=Pos+Derivation=FutNom+PersonNumber=A3sg+Possessive=P3sg+Case=Gen'],
#  ['belirlenmAsInIn',
#   'belirle+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Gen'],
#  ['seçIlmAsIdIr',
#   'seç+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['kesIp', 'kes+VERB+Polarity=Pos+Derivation=After'],
#  ['boyayErEK', 'boya+VERB+Polarity=Pos+Derivation=Ger'],
#  ['yapDIKI', 'yap+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['verDIKI', 'ver+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['gelişDIrDI',
#   'geliş+VERB+Derivation=Cau+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['korunmAsI',
#   'koru+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['olmA',
#   'ol+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['edIlmAyAcAKI',
#   'et+VERB+Derivation=Pass+Polarity=Neg+Derivation=FutNom+PersonNumber=A3sg+Possessive=P3sg+Case=Nom'],
#  ['bilDIrIlDI',
#   'bil+VERB+Derivation=Cau+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['kullanmAyA',
#   'kullan+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat'],
#  ['gelIrken',
#   'gel+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg+Derivation=While'],
#  ['durDI',
#   'dur+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['atIşlArINDA',
#   'at+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3pl+Possessive=P3sg+Case=Loc'],
#  ['kaçIrDIKI',
#   'kaç+VERB+Derivation=Cau+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['kazanmA',
#   'kazan+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['verDI',
#   'ver+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['kaçIrmAsIYlA',
#   'kaç+VERB+Derivation=Cau+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Ins'],
#  ['kazanDI',
#   'kazan+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['savaşIrken',
#   'savaş+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg+Derivation=While'],
#  ['çizAbilmAk',
#   'çiz+VERB+Derivation=Able+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['durdIrDIKI',
#   'dur+VERB+Derivation=Cau+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Nom'],
#  ['söylenmAkteDIr',
#   'söyle+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg'],
#  ['öğrenmAkDA',
#   'öğren+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Loc'],
#  ['keşfetmAkDA',
#   'keşfet+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Loc'],
#  ['atAcAKInIz', 'at+VERB+Polarity=Pos+Derivation=FutPart+Possessive=P2pl'],
#  ['anlamAkDA',
#   'anla+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Loc'],
#  ['kullanAbilAcAKInIz',
#   'kullan+VERB+Derivation=Able+Polarity=Pos+Derivation=FutPart+Possessive=P2pl'],
#  ['kılavuz',
#   'kılavuz+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=PresCop+PersonNumber=V3sg'],
#  ['boşalTmAsI',
#   'boşal+VERB+Derivation=Cau+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['dönDI',
#   'dön+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['araştırmAlAr',
#   'araştır+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3pl+Possessive=Pnon+Case=Nom'],
#  ['etsA',
#   'et+VERB+Polarity=Pos+TenseAspectMood=Desr+Copula=PresCop+PersonNumber=V3pl'],
#  ['araştırmAlAr',
#   'araştır+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3pl+Possessive=Pnon+Case=Nom'],
#  ['olmADIKInI',
#   'ol+VERB+Polarity=Neg+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['göstermIşDIr',
#   'göster+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3pl'],
#  ['yapDI',
#   'yap+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['kurIlDIKI',
#   'kur+VERB+Derivation=Pass+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Nom'],
#  ['bilInmAkteDIr',
#   'bil+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg'],
#  ['gelmAkteDIr',
#   'gel+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg'],
#  ['anlayIşInI',
#   'anla+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['artırDI',
#   'artır+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['varDIr',
#   'var+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['yaylaYAn', 'yayla+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['yaraDI',
#   'yara+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['çizmAyA',
#   'çiz+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat'],
#  ['verDIKI',
#   'ver+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['çalışmAyA',
#   'çalış+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat'],
#  ['başlamIşDIr',
#   'başla+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['eğDI',
#   'eğ+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['etDI',
#   'et+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['alDI',
#   'al+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['katletDI',
#   'katlet+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['etmAk',
#   'et+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['gönderDI',
#   'gönder+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['yaşamA',
#   'yaşa+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['olIp', 'ol+VERB+Polarity=Pos+Derivation=After'],
#  ['kastetmAkteDIr',
#   'kastet+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg'],
#  ['olmAlIDIr',
#   'ol+VERB+Polarity=Pos+TenseAspectMood=Nec+Copula=GenCop+PersonNumber=V3sg'],
#  ['öğrenDI',
#   'öğren+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['göstermAkteDIr',
#   'göster+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg'],
#  ['yönetAn', 'yönet+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['artDIrIlmAsI',
#   'art+VERB+Derivation=Cau+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['yönelTmIşDIr',
#   'yönel+VERB+Derivation=Cau+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['bulunmAkta',
#   'bulun+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=PresCop+PersonNumber=V3pl'],
#  ['edIlmAkteDIr',
#   'et+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg'],
#  ['gösterAn', 'göster+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['çekmAlAr',
#   'çek+VERB+Derivation=Rcp+Polarity=Pos+Derivation=Nonf+PersonNumber=A3pl+Possessive=Pnon+Case=Bare'],
#  ['çekmAlArI',
#   'çek+VERB+Derivation=Rcp+Polarity=Pos+Derivation=Nonf+PersonNumber=A3pl+Possessive=Pnon+Case=Acc'],
#  ['girmAlArI',
#   'gir+VERB+Derivation=Rcp+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3pl+Case=Nom'],
#  ['sarsmAğA',
#   'sars+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat'],
#  ['başlamIş',
#   'başla+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=PresCop+PersonNumber=V3pl'],
#  ['etmAk',
#   'et+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['gitmIşlArDI',
#   'git+VERB+Polarity=Pos+TenseAspectMood=Nar+PersonNumber=V3pl+Copula=PastCop'],
#  ['olmAsInA',
#   'ol+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Dat'],
#  ['alDI',
#   'al+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['oynamAyA',
#   'oyna+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat'],
#  ['başlaDI',
#   'başla+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['oynanAn',
#   'oyna+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['yapmA[Y]I',
#   'yap+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Acc'],
#  ['başarDI',
#   'başar+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['yapDI',
#   'yap+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['alDIKI', 'al+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['etDI',
#   'et+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['dayanAn', 'dayan+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['olmAYAn', 'ol+VERB+Polarity=Neg+Derivation=PresPart+Possessive=Pnon'],
#  ['etmAyA',
#   'et+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat'],
#  ['yönelTAn',
#   'yönel+VERB+Derivation=Cau+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['arınmIş', 'arın+VERB+Polarity=Pos+Derivation=PerPart+Possessive=Pnon'],
#  ['yaratmAkDAn',
#   'yarat+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Abl'],
#  ['duyDIKI', 'duy+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['koymAktaDIr',
#   'koy+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3pl'],
#  ['bulunIr',
#   'bulun+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl'],
#  ['söylenIş',
#   'söyle+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['tartışmA',
#   'tartış+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['konusIdIr',
#   'konu+VERB+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['faringealDIr',
#   'faringeal+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['başlaTErEK', 'başla+VERB+Derivation=Cau+Polarity=Pos+Derivation=Ger'],
#  ['öldürmAk',
#   'öl+VERB+Derivation=Cau+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['gütmIşlArDIr',
#   'güt+VERB+Polarity=Pos+TenseAspectMood=Nar+PersonNumber=V3pl+Copula=GenCop'],
#  ['gösterDIKI',
#   'göster+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['koşIcIlArIn',
#   'koş+VERB+Polarity=Pos+Derivation=Inh+PersonNumber=A3pl+Possessive=Pnon+Case=Gen'],
#  ['düşErEK', 'düş+VERB+Polarity=Pos+Derivation=Ger'],
#  ['geçmAsI',
#   'geç+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['verIlebIlIr',
#   'ver+VERB+Derivation=Pass+Derivation=Able+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['korunIr',
#   'koru+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['taşınabIlIr',
#   'taşı+VERB+Derivation=Pass+Derivation=Able+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl'],
#  ['çalAcAK', 'çal+VERB+Polarity=Pos+Derivation=FutPart+Possessive=Pnon'],
#  ['verIlAn',
#   'ver+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['katılDI',
#   'katıl+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['katılAn', 'katıl+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['ilerleYAn', 'ilerle+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['katılmAk',
#   'katıl+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['istenAn',
#   'iste+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['verIlmIşDIr',
#   'ver+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['yenIlIp', 'yen+VERB+Derivation=Pass+Polarity=Pos+Derivation=After'],
#  ['çekIlDI',
#   'çek+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['katılDIKI', 'katıl+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['verAn', 'ver+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['alDIKI', 'al+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['fasıl',
#   'fasıl+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=PresCop+PersonNumber=V3sg'],
#  ['giyDI',
#   'giy+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['yükselDI',
#   'yüksel+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['yağDI',
#   'yağ+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['olmADIKI',
#   'ol+VERB+Polarity=Neg+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['etDIlAr',
#   'et+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl'],
#  ['savunmAnIn',
#   'savun+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Gen'],
#  ['açIlAn',
#   'aç+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['müfrezeDIr',
#   'müfreze+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['yapDIrAn',
#   'yap+VERB+Derivation=Cau+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['komutanIdIr',
#   'komutan+VERB+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['çalışmAz',
#   'çalış+VERB+Polarity=Neg+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['gelIr',
#   'gel+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['beğenmAz',
#   'beğen+VERB+Polarity=Neg+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['dövIr',
#   'döv+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['direTErEK', 'dire+VERB+Derivation=Cau+Polarity=Pos+Derivation=Ger'],
#  ['etmAsInI',
#   'et+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['sağlar',
#   'sağla+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['denAn',
#   'de+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['taşıyorlArDI',
#   'taşı+VERB+Polarity=Pos+TenseAspectMood=Prog1+PersonNumber=V3pl+Copula=PastCop'],
#  ['düşsAlAr',
#   'düş+VERB+Polarity=Pos+TenseAspectMood=Desr+Copula=PresCop+PersonNumber=V3pl'],
#  ['sürIrken',
#   'sür+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg+Derivation=While'],
#  ['durdurErEK', 'dur+VERB+Derivation=Cau+Polarity=Pos+Derivation=Ger'],
#  ['koşAn', 'koş+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['çarpmAsInI',
#   'çarp+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['sağlaDI',
#   'sağla+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['değDIrIlmAsIYlA',
#   'değ+VERB+Derivation=Cau+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Ins'],
#  ['çıkarIlDIKI',
#   'çıkar+VERB+Derivation=Pass+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['anlamAk',
#   'anla+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Nom'],
#  ['değilDIr',
#   'değil+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['yokDIr',
#   'yok+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['duyIrIlIr',
#   'duy+VERB+Derivation=Cau+Derivation=Pass+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['birisIydI',
#   'biri+VERB+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Copula=PastCop+PersonNumber=V3pl'],
#  ['vermAk',
#   'ver+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Nom'],
#  ['olağanDIr',
#   'olağan+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['oldIkCA', 'ol+VERB+Polarity=Pos+Derivation=As'],
#  ['şımarTIyorDI',
#   'şımar+VERB+Derivation=Cau+Polarity=Pos+TenseAspectMood=Prog1+Copula=PastCop+PersonNumber=V3sg'],
#  ['etDI',
#   'et+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['yükselmA[Y]I',
#   'yüksel+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Acc'],
#  ['kapDIrAn',
#   'kap+VERB+Derivation=Cau+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['atlatamAyAcAk',
#   'atlat+VERB+Derivation=Able+Polarity=Neg+TenseAspectMood=Fut+Copula=PresCop+PersonNumber=V3pl'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['büyüyAcAkDI',
#   'büyü+VERB+Polarity=Pos+TenseAspectMood=Fut+Copula=PastCop+PersonNumber=V3sg'],
#  ['incelemAk',
#   'incele+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['gönderIlDI',
#   'gönder+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['öldIrDIKI',
#   'öl+VERB+Derivation=Cau+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['bulanmIş',
#   'bula+VERB+Derivation=Pass+Polarity=Pos+Derivation=PerPart+Possessive=Pnon'],
#  ['bulunmAktaDIr',
#   'bulun+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg'],
#  ['etDIlAr',
#   'et+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl'],
#  ['olmAsI',
#   'ol+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Nom'],
#  ['edIlDIKI',
#   'et+VERB+Derivation=Pass+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['alInmIşDIr',
#   'al+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['çalInmIş',
#   'çal+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Nar+Copula=PresCop+PersonNumber=V3sg'],
#  ['olmA',
#   'ol+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Nom'],
#  ['geçIrlIyDI',
#   'geç+VERB+Polarity=Pos+Derivation=AorNom+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=PastCop+PersonNumber=V3sg'],
#  ['dönIş',
#   'dön+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['alDI',
#   'al+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['girIr',
#   'gir+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['serIr',
#   'ser+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['gelAnlArlA',
#   'gel+VERB+Polarity=Pos+Derivation=PresNom+PersonNumber=A3pl+Possessive=Pnon+Case=Ins'],
#  ['görIr',
#   'gör+VERB+Derivation=Rcp+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['çıkIr',
#   'çık+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl'],
#  ['sayIlabIlIr',
#   'say+VERB+Derivation=Pass+Derivation=Able+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['uğramAkta',
#   'uğra+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=PresCop+PersonNumber=V3sg'],
#  ['olDIKI',
#   'ol+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['almADAn',
#   'al+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Abl'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['olmAk',
#   'ol+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['edIr',
#   'et+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['çalışmAlArI',
#   'çalış+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3pl+Possessive=P3sg+Case=Bare'],
#  ['giyDIKI', 'giy+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['olDI',
#   'ol+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['yapDI',
#   'yap+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['bulunIr',
#   'bulun+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['oynar',
#   'oyna+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl'],
#  ['çıkAn', 'çık+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['yanIp', 'yan+VERB+Polarity=Pos+Derivation=After'],
#  ['kalmIşDIr',
#   'kal+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3pl'],
#  ['taşıYAn', 'taşı+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['oğullArIDIr',
#   'oğul+VERB+PersonNumber=A3sg+Possessive=P3pl+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['doldIrIlIr',
#   'dol+VERB+Derivation=Cau+Derivation=Pass+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl'],
#  ['katılAn', 'katıl+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['savaşmA[Y]I',
#   'savaş+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Acc'],
#  ['almIşlArDAn',
#   'al+VERB+Polarity=Pos+Derivation=PerNom+PersonNumber=A3pl+Possessive=Pnon+Case=Abl'],
#  ['oluşmIşDI',
#   'oluş+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=PastCop+PersonNumber=V3sg'],
#  ['kalIrken',
#   'kal+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl+Derivation=While'],
#  ['kaldırmAnIn',
#   'kaldır+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Gen'],
#  ['olDIKInA',
#   'ol+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Dat'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['incelemAyA',
#   'incele+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat'],
#  ['başlaDI',
#   'başla+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['katılDI',
#   'katıl+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['yakIyorIz',
#   'yak+VERB+Polarity=Pos+TenseAspectMood=Prog1+Copula=PresCop+PersonNumber=V1pl'],
#  ['yapDIKInIz', 'yap+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P2pl'],
#  ['yakIyorIz',
#   'yak+VERB+Polarity=Pos+TenseAspectMood=Prog1+Copula=PresCop+PersonNumber=V1pl'],
#  ['gelişmA',
#   'geliş+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['çıkmAlArInA',
#   'çık+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3pl+Case=Dat'],
#  ['kullanIlmADI',
#   'kullan+VERB+Derivation=Pass+Polarity=Neg+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl'],
#  ['etmIşDIr',
#   'et+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['çalışAcAK',
#   'çalış+VERB+Polarity=Pos+Derivation=FutNom+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['olmADIKInDAn',
#   'ol+VERB+Polarity=Neg+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Abl'],
#  ['çalışmAktaDIr',
#   'çalış+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg'],
#  ['gelişDIrmIşDIr',
#   'geliş+VERB+Derivation=Cau+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['içerAn', 'içer+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['bilInIrDI',
#   'bil+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Aor+Copula=PastCop+PersonNumber=V3sg'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['gelIr',
#   'gel+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['çalışAn', 'çalış+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['sürIcIlArInI',
#   'sür+VERB+Polarity=Pos+Derivation=Inh+PersonNumber=A3pl+Possessive=P3sg+Case=Acc'],
#  ['sunmIşDIr',
#   'sun+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['alInIp', 'al+VERB+Derivation=Pass+Polarity=Pos+Derivation=After'],
#  ['çıkarIlmAdan', 'çıkar+VERB+Derivation=Pass+Polarity=Neg+Derivation=Ger'],
#  ['gelmAsInDAn',
#   'gel+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Abl'],
#  ['gönderIlDI',
#   'gönder+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['yürüyIşA',
#   'yürü+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat'],
#  ['anDIrAn',
#   'an+VERB+Derivation=Cau+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['edIlIr',
#   'et+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['soruşturmA',
#   'soruştur+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['silInmAsI',
#   'sil+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['katılamAmA',
#   'katıl+VERB+Polarity=Pos+Derivation=Able+Polarity=Neg+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['verIlDI',
#   'ver+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['kaldırIlmAsI',
#   'kaldır+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['verIlmIşDIr',
#   'ver+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['bulunDIKI', 'bulun+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['kurtulIş',
#   'kurtul+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['çıkAn', 'çık+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['anlayIşI',
#   'anla+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Acc'],
#  ['doğurmIşTur',
#   'doğ+VERB+Derivation=Cau+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3pl'],
#  ['çıkAn', 'çık+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['atDI',
#   'at+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['gelAn',
#   'gel+VERB+Polarity=Pos+Proper=True+Derivation=PresPart+Possessive=Pnon+Proper=True'],
#  ['kurIlIşI',
#   'kur+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Nom'],
#  ['kalDIKI', 'kal+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['kurtulIşI',
#   'kurtul+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Acc'],
#  ['aramAyA',
#   'ara+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat'],
#  ['sunmIşDIr',
#   'sun+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['getirAn', 'getir+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['dönemADI',
#   'dön+VERB+Derivation=Able+Polarity=Neg+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['yapIlIr',
#   'yap+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['varDIr',
#   'var+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3pl'],
#  ['bulunIr',
#   'bulun+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['oluşTIrIr',
#   'oluş+VERB+Derivation=Cau+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['almAk',
#   'al+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['isteDI',
#   'iste+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl'],
#  ['sürAn', 'sür+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['kuşatmAsI',
#   'kuşat+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Nom'],
#  ['tükenmAsI',
#   'tüken+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['kaldırIlmAk',
#   'kaldır+VERB+Derivation=Pass+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['kalInDI',
#   'kal+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['çekIlmAsIYlA',
#   'çek+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Ins'],
#  ['uzamAyA',
#   'uza+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat'],
#  ['edIrmIş',
#   'et+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=EvCop+PersonNumber=V3pl'],
#  ['görInIr',
#   'gör+VERB+Derivation=Rfx+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['yaşıyor',
#   'yaşa+VERB+Polarity=Pos+TenseAspectMood=Prog1+Copula=PresCop+PersonNumber=V3sg'],
#  ['sanIlmAsInA',
#   'san+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Dat'],
#  ['olIr',
#   'ol+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['olDIKI', 'ol+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['yaşanmAktaDIr',
#   'yaşa+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['kullanIlmIşDIr',
#   'kullan+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['oldIkCA', 'ol+VERB+Polarity=Pos+Derivation=As'],
#  ['ağırDIr',
#   'ağır+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3pl'],
#  ['yazDIKI', 'yaz+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['yerleşmAsInIn',
#   'yerleş+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Gen'],
#  ['olAbilmAk',
#   'ol+VERB+Derivation=Able+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['varsA',
#   'var+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=CndCop+PersonNumber=V3sg'],
#  ['yapacağIm',
#   'yap+VERB+Polarity=Pos+TenseAspectMood=Fut+Copula=PresCop+PersonNumber=V1sg'],
#  ['yaklaşIncA', 'yaklaş+VERB+Polarity=Pos+Derivation=When'],
#  ['yapIlAcAK',
#   'yap+VERB+Derivation=Pass+Polarity=Pos+Derivation=FutPart+Possessive=Pnon'],
#  ['ulaşDIrmA',
#   'ulaş+VERB+Derivation=Cau+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['etmAkteDIr',
#   'et+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3pl'],
#  ["asur'DAyDI",
#   'asur+VERB+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Loc+Copula=PastCop+PersonNumber=V3sg'],
#  ['kesIr',
#   'kes+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['fırlaDIr',
#   'fırla+VERB+Derivation=Cau+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['olmAk',
#   'ol+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['edIlDI',
#   'et+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl'],
#  ['yazDIKlArInA',
#   'yaz+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3pl+Possessive=P3sg+Case=Dat'],
#  ['oturmAmAş',
#   'otur+VERB+Polarity=Neg+TenseAspectMood=Nar+Copula=PresCop+PersonNumber=V3sg'],
#  ['yapmAmAş',
#   'yap+VERB+Polarity=Neg+TenseAspectMood=Nar+Copula=PresCop+PersonNumber=V3sg'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['olmIşDIr',
#   'ol+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3pl'],
#  ['olmAk',
#   'ol+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['isteDIKInI',
#   'iste+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['söyleDI',
#   'söyle+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['olDIKInI',
#   'ol+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['yapmADIKInI',
#   'yap+VERB+Polarity=Neg+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['söyleDIlAr',
#   'söyle+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl'],
#  ['edIlAn',
#   'et+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['ilkDIr',
#   'ilk+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3pl'],
#  ['uğraDI',
#   'uğra+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['yapIlAn',
#   'yap+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['görmA',
#   'gör+VERB+Derivation=Rcp+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['yapIlAn',
#   'yap+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['alDI',
#   'al+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['karşılayAcAK',
#   'karşıla+VERB+Polarity=Pos+Derivation=FutPart+Possessive=Pnon'],
#  ['yenIp', 'yen+VERB+Polarity=Pos+Derivation=After'],
#  ['kalDIKImIz', 'kal+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P1pl'],
#  ['ısıtIlAn',
#   'ısıt+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['yıkanIrDI',
#   'yıka+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Aor+Copula=PastCop+PersonNumber=V3sg'],
#  ['etDIlAr',
#   'et+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl'],
#  ['yerleşDIKlArI',
#   'yerleş+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3pl'],
#  ['vermIşlArDIr',
#   'ver+VERB+Polarity=Pos+TenseAspectMood=Nar+PersonNumber=V3pl+Copula=GenCop'],
#  ['almIşDIr',
#   'al+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['görIlDIKI',
#   'gör+VERB+Derivation=Pass+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['yüksekDAyDI',
#   'yüksek+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Loc+Copula=PastCop+PersonNumber=V3pl'],
#  ['seçIlAn',
#   'seç+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['sunAbilIrDI',
#   'sun+VERB+Derivation=Able+Polarity=Pos+TenseAspectMood=Aor+Copula=PastCop+PersonNumber=V3sg'],
#  ['edIlDIKI',
#   'et+VERB+Derivation=Pass+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['gelAnlArIn',
#   'gel+VERB+Polarity=Pos+Derivation=PresNom+PersonNumber=A3pl+Possessive=Pnon+Case=Gen'],
#  ['yapIlDIKI',
#   'yap+VERB+Derivation=Pass+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Nom'],
#  ['görIlIr',
#   'gör+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['büyükDIr',
#   'büyük+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['bilInDIKI',
#   'bil+VERB+Derivation=Pass+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['olDIKI', 'ol+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['yazIlmIşDIr',
#   'yaz+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['kurmAlArI',
#   'kur+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3pl+Case=Nom'],
#  ['gerekDIKInI',
#   'gerek+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['savunAn', 'savun+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['düşmAmAk',
#   'düş+VERB+Polarity=Neg+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['etmAk',
#   'et+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['vermAyA',
#   'ver+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat'],
#  ['başlaDI',
#   'başla+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['kaybedAn', 'kaybet+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['napAcAKI',
#   'nap+VERB+Polarity=Pos+Derivation=FutNom+PersonNumber=A3sg+Possessive=P3sg+Case=Nom'],
#  ['beklenIrken',
#   'bekle+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg+Derivation=While'],
#  ['ayrılIp', 'ayır+VERB+Derivation=Pass+Polarity=Pos+Derivation=After'],
#  ['gitmAsIYlA',
#   'git+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Ins'],
#  ['gitmAyA',
#   'git+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat'],
#  ['başlaDI',
#   'başla+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl'],
#  ['olDI',
#   'ol+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['kazanAbilDI',
#   'kazan+VERB+Derivation=Able+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['olDIKI',
#   'ol+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['satIşA',
#   'sat+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat'],
#  ['çıkmIş',
#   'çık+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=PresCop+PersonNumber=V3sg'],
#  ['vermIşDIr',
#   'ver+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['anmAk',
#   'an+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['edIlDI',
#   'et+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['sağlaYAnlAr',
#   'sağla+VERB+Polarity=Pos+Derivation=PresNom+PersonNumber=A3pl+Possessive=Pnon+Case=Nom'],
#  ['bulunAn', 'bulun+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['incelenIp', 'incele+VERB+Derivation=Pass+Polarity=Pos+Derivation=After'],
#  ['değitirmAklAr',
#   'değiş+VERB+Derivation=Cau+Polarity=Pos+Derivation=Nonf+PersonNumber=A3pl+Possessive=Pnon+Case=Nom'],
#  ['yapIlAcAKI',
#   'yap+VERB+Derivation=Pass+Polarity=Pos+Derivation=FutNom+PersonNumber=A3sg+Possessive=P3sg+Case=Nom'],
#  ['edIlDI',
#   'et+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['olmAsInA',
#   'ol+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Dat'],
#  ['duyDIKI', 'duy+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['basIyor',
#   'bas+VERB+Polarity=Pos+TenseAspectMood=Prog1+Copula=PresCop+PersonNumber=V3sg'],
#  ['geçIş',
#   'geç+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Nom'],
#  ['yapIlAn',
#   'yap+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['girIlmIş',
#   'gir+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Nar+Copula=PresCop+PersonNumber=V3sg'],
#  ['olmAk',
#   'ol+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['edIlmAyA',
#   'et+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat'],
#  ['başlamIşDIr',
#   'başla+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['yatIrlIr',
#   'yat+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl'],
#  ['yapsA',
#   'yap+VERB+Polarity=Pos+TenseAspectMood=Desr+Copula=PresCop+PersonNumber=V3sg'],
#  ['sevemAyAcAKInI',
#   'sev+VERB+Derivation=Able+Polarity=Neg+Derivation=FutNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['olDIKInI',
#   'ol+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['anlayIncA', 'anla+VERB+Polarity=Pos+Derivation=When'],
#  ['boşanIrlIr',
#   'boşa+VERB+Derivation=Rfx+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl'],
#  ['görIlDIKI',
#   'gör+VERB+Derivation=Pass+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['etmAkteyDI',
#   'et+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=PastCop+PersonNumber=V3sg'],
#  ['toplayamADI',
#   'topla+VERB+Derivation=Able+Polarity=Neg+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['dağıtAcAKInI',
#   'dağıt+VERB+Polarity=Pos+Derivation=FutNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['duyurDI',
#   'duy+VERB+Derivation=Cau+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['olAbIlAcAKI',
#   'ol+VERB+Derivation=Able+Polarity=Pos+Derivation=FutNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['sürIcIlArI',
#   'sür+VERB+Polarity=Pos+Derivation=Inh+PersonNumber=A3pl+Possessive=P3sg+Case=Bare'],
#  ['edIlDI',
#   'et+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['açDIKInI',
#   'aç+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['savunuyorDI',
#   'savun+VERB+Polarity=Pos+TenseAspectMood=Prog1+Copula=PastCop+PersonNumber=V3sg'],
#  ['izleYAn', 'izle+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['geçIr',
#   'geç+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl'],
#  ['gelişDIrIlmIşDIr',
#   'geliş+VERB+Derivation=Cau+Derivation=Pass+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3pl'],
#  ['geçirDIKI', 'geçir+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['vurDI',
#   'vur+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['yazDIKI', 'yaz+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['gelmIşDIr',
#   'gel+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['küçülTIcI',
#   'küçül+VERB+Derivation=Cau+Polarity=Pos+Derivation=Inh+Possessive=Pnon'],
#  ['bulInErEK', 'bul+VERB+Derivation=Pass+Polarity=Pos+Derivation=Ger'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['kullanIlmAYAn',
#   'kullan+VERB+Derivation=Pass+Polarity=Neg+Derivation=PresPart+Possessive=Pnon'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['kullanIlmAktaDIr',
#   'kullan+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg'],
#  ['duymAktayDI',
#   'duy+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=PastCop+PersonNumber=V3sg'],
#  ['çıkarIlDI',
#   'çıkar+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['kavuşDIKI', 'kavuş+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['doğAn', 'doğ+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['birIdIr',
#   'bir+VERB+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['bulInmIşDIr',
#   'bul+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3pl'],
#  ["çarpIşmAsI'NDA",
#   'çarp+VERB+Proper=True+Derivation=Rcp+Polarity=Pos+Proper=True+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Apostrophe=True+Case=Loc+Proper=True'],
#  ['yenIlDI',
#   'yen+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['çalışmAlArI',
#   'çalış+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3pl+Possessive=P3sg+Case=Nom'],
#  ['etmAkteDIr',
#   'et+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3pl'],
#  ['oynanDI',
#   'oyna+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['kazanDI',
#   'kazan+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['alIyor',
#   'al+VERB+Polarity=Pos+TenseAspectMood=Prog1+Copula=PresCop+PersonNumber=V3sg'],
#  ['sağlaDI',
#   'sağla+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['kaldırIlDI',
#   'kaldır+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['borsalArDIr',
#   'borsa+VERB+PersonNumber=A3pl+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ["parketthandel'DIr",
#   'parketthandel+VERB+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg+Proper=True'],
#  ['başlaDI',
#   'başla+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl'],
#  ['geçDI',
#   'geç+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['artIr',
#   'art+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['gelişDIrIlAn',
#   'geliş+VERB+Derivation=Cau+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['tartışIlAn',
#   'tartış+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['oluşTurAn',
#   'oluş+VERB+Derivation=Cau+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['oluşmAktadırlAr',
#   'oluş+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3pl'],
#  ['kurIlIşlArInDAn',
#   'kur+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3pl+Possessive=P3sg+Case=Abl'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['başlaDI',
#   'başla+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['titreşAn',
#   'titre+VERB+Derivation=Rcp+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['yayIlmA',
#   'yay+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['çıkmIş',
#   'çık+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=PresCop+PersonNumber=V3sg'],
#  ['olDI',
#   'ol+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['başlaYAn', 'başla+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['girAn', 'gir+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['yıkIlmAsI',
#   'yık+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
# ...
#   'dur+VERB+Derivation=Cau+Derivation=Able+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['kullanIlIr',
#   'kullan+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['olmIşDIr',
#   'ol+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['iyiDIr',
#   'iyi+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['artIşlAr',
#   'art+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3pl+Possessive=Pnon+Case=Nom'],
#  ['gönderIlmAsInIn',
#   'gönder+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Gen'],
#  ['bulunmAsI',
#   'bulun+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['içinDIr',
#   'için+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['girErEK', 'gir+VERB+Polarity=Pos+Derivation=Ger'],
#  ['donanmA',
#   'donan+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['görDI',
#   'gör+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['çıkarTIlDI',
#   'çıkar+VERB+Derivation=Cau+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl'],
#  ['değişDIrIlDI',
#   'değiş+VERB+Derivation=Cau+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl'],
#  ['soruşturmAsINDA',
#   'soruştur+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Loc'],
#  ['etDIKI',
#   'et+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['i̇DI',
#   'i+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['varmAkta',
#   'var+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=PresCop+PersonNumber=V3sg'],
#  ['olDIKInI',
#   'ol+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['öğrenIncA', 'öğren+VERB+Polarity=Pos+Derivation=When'],
#  ['şaşırmIş',
#   'şaşır+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=PresCop+PersonNumber=V3sg'],
#  ['kuşatmA[Y]I',
#   'kuşat+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Acc'],
#  ['kaldırErEK', 'kaldır+VERB+Polarity=Pos+Derivation=Ger'],
#  ['çekIlmIşDIr',
#   'çek+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['içerAn', 'içer+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['uymADIKI',
#   'uy+VERB+Polarity=Neg+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['tırmalamAyor',
#   'tırmala+VERB+Polarity=Neg+TenseAspectMood=Prog1+Copula=PresCop+PersonNumber=V3sg'],
#  ['olmAsI',
#   'ol+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Nom'],
#  ['nedenlADIr',
#   'neden+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Ins+Copula=GenCop+PersonNumber=V3sg'],
#  ['sayAn', 'say+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['bulunDI',
#   'bulun+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['geçIş',
#   'geç+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Nom'],
#  ['yayIlDI',
#   'yay+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['olDIKInI',
#   'ol+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['göstermAkteDIr',
#   'göster+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg'],
#  ['gelAn', 'gel+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['olDIKI',
#   'ol+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Nom'],
#  ['görIlDI',
#   'gör+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['başlanDI',
#   'başla+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['yönetIcI',
#   'yönet+VERB+Polarity=Pos+Derivation=Inh+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['olDIKlArINI',
#   'ol+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3pl+Case=Acc'],
#  ['etmAklA',
#   'et+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Ins'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['kurmIşlArDIr',
#   'kur+VERB+Polarity=Pos+TenseAspectMood=Nar+PersonNumber=V3pl+Copula=GenCop'],
#  ['kazanmA',
#   'kazan+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['göstermIşDIr',
#   'göster+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['içerAn', 'içer+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['basIlmIşDIr',
#   'bas+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3pl'],
#  ['geçAn', 'geç+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['oluşTuruyorDI',
#   'oluş+VERB+Derivation=Cau+Polarity=Pos+TenseAspectMood=Prog1+Copula=PastCop+PersonNumber=V3pl'],
#  ['başkasIdIr',
#   'başka+VERB+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['girmA',
#   'gir+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['küçümser',
#   'küçümse+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['girIrsA',
#   'gir+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=CndCop+PersonNumber=V3sg'],
#  ['olAcAKInA',
#   'ol+VERB+Polarity=Pos+Derivation=FutNom+PersonNumber=A3sg+Possessive=P3sg+Case=Dat'],
#  ['verIr',
#   'ver+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['bilInAn',
#   'bil+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['kurtulIş',
#   'kurtul+VERB+Polarity=Pos+Proper=True+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True'],
#  ['atAcAk',
#   'at+VERB+Polarity=Pos+TenseAspectMood=Fut+Copula=PresCop+PersonNumber=V3sg'],
#  ['sürAn', 'sür+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['kaybedAcAkDIr',
#   'kaybet+VERB+Polarity=Pos+TenseAspectMood=Fut+Copula=GenCop+PersonNumber=V3pl'],
#  ['olsA',
#   'ol+VERB+Polarity=Pos+TenseAspectMood=Desr+Copula=PresCop+PersonNumber=V3sg'],
#  ['önermIşDIr',
#   'öner+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['dağılmAsI',
#   'dağıl+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['ermAsIYlA',
#   'er+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Ins'],
#  ['benimsemA',
#   'benimse+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['ayrılErEK', 'ayır+VERB+Derivation=Pass+Polarity=Pos+Derivation=Ger'],
#  ['benimsemIş',
#   'benimse+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=PresCop+PersonNumber=V3sg'],
#  ['yapIlmAsInA',
#   'yap+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Dat'],
#  ['vermIşDIr',
#   'ver+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['işleTAn',
#   'işle+VERB+Derivation=Cau+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['tanışIrlIr',
#   'tanı+VERB+Derivation=Rcp+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl'],
#  ['kurIlAn',
#   'kur+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['kurIlDI',
#   'kur+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['aramAyA',
#   'ara+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat'],
#  ['başlarlIr',
#   'başla+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl'],
#  ['almIşDIr',
#   'al+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3pl'],
#  ['yazmAmAşlArDIr',
#   'yaz+VERB+Polarity=Neg+TenseAspectMood=Nar+PersonNumber=V3pl+Copula=GenCop'],
#  ['başlaTIlmAsINDA',
#   'başla+VERB+Derivation=Cau+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Loc'],
#  ['kullanIlabIlIr',
#   'kullan+VERB+Derivation=Pass+Derivation=Able+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['beğenIyor',
#   'beğen+VERB+Polarity=Pos+TenseAspectMood=Prog1+Copula=PresCop+PersonNumber=V3sg'],
#  ['buluşmA[Y]I',
#   'buluş+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Acc'],
#  ['istiyorDI',
#   'iste+VERB+Polarity=Pos+TenseAspectMood=Prog1+Copula=PastCop+PersonNumber=V3sg'],
#  ['çevirmAk',
#   'çevir+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Nom'],
#  ['gerekIrsA',
#   'gerek+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=CndCop+PersonNumber=V3sg'],
#  ['atamA',
#   'ata+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['tablosI',
#   'tablo+VERB+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Copula=PresCop+PersonNumber=V3sg'],
#  ['çekIlmAsInDAn',
#   'çek+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Abl'],
#  ['düşAn', 'düş+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['saldırAcAkDIr',
#   'saldır+VERB+Polarity=Pos+TenseAspectMood=Fut+Copula=GenCop+PersonNumber=V3sg'],
#  ['edErEK', 'et+VERB+Polarity=Pos+Derivation=Ger'],
#  ['bölInDIKI',
#   'böl+VERB+Derivation=Pass+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['görIlAn',
#   'gör+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['koyDIlAr',
#   'koy+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl'],
#  ['verDI',
#   'ver+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['verDIKI', 'ver+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['beğenDIKInI',
#   'beğen+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['getirErEK', 'getir+VERB+Polarity=Pos+Derivation=Ger'],
#  ['olmAk',
#   'ol+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['acımAsIzcA',
#   'acı+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Wout+Derivation=Ly'],
#  ['eleştirmAnIn',
#   'eleştir+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Gen'],
#  ['edIyor',
#   'et+VERB+Polarity=Pos+TenseAspectMood=Prog1+Copula=PresCop+PersonNumber=V3sg'],
#  ['bulunDI',
#   'bulun+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['gitDI',
#   'git+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['duyDIKI', 'duy+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['tanışDI',
#   'tanı+VERB+Derivation=Rcp+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['getirmIşDI',
#   'getir+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=PastCop+PersonNumber=V3sg'],
#  ['geçmIşDIr',
#   'geç+VERB+Polarity=Pos+TenseAspectMood=Nar+Copula=GenCop+PersonNumber=V3sg'],
#  ['getirmAkteDIr',
#   'getir+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg'],
#  ['keşfedIldIkCA', 'keşfet+VERB+Derivation=Pass+Polarity=Pos+Derivation=As'],
#  ['yapAbilAcAKlArI',
#   'yap+VERB+Derivation=Able+Polarity=Pos+Derivation=FutPart+Possessive=P3pl'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['aramAyA',
#   'ara+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Dat'],
#  ['koyIldIlAr',
#   'koy+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl'],
#  ['doğDIKInI',
#   'doğ+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Acc'],
#  ['anlaTsAda',
#   'anla+VERB+Derivation=Cau+Polarity=Pos+TenseAspectMood=Desr+Copula=PresCop+PersonNumber=V3sg'],
#  ['yazDIKI', 'yaz+VERB+Polarity=Pos+Derivation=PastPart+Possessive=P3sg'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['yaşamIş', 'yaşa+VERB+Polarity=Pos+Derivation=PerPart+Possessive=Pnon'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['doğDI',
#   'doğ+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['olDIKINDA',
#   'ol+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Loc'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['kurtulAbilIr',
#   'kurtul+VERB+Derivation=Able+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['olAbilIr',
#   'ol+VERB+Derivation=Able+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['etmA[Y]I',
#   'et+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Acc'],
#  ['başarAn', 'başar+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['götürDI',
#   'götür+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['alInmAsI',
#   'al+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['bulInIr',
#   'bul+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['olDIKI',
#   'ol+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['birIdIr',
#   'bir+VERB+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['emIr',
#   'em+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['büyür',
#   'büyü+VERB+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['yazIlAn',
#   'yaz+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['açDI',
#   'aç+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['olAn', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['bulunAn', 'bulun+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['merkezIdIr',
#   'merkez+VERB+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Copula=GenCop+PersonNumber=V3sg'],
#  ['olErEK', 'ol+VERB+Polarity=Pos+Derivation=Ger'],
#  ['konumINDAdIr',
#   'konum+VERB+PersonNumber=A3sg+Possessive=P3sg+Case=Loc+Copula=GenCop+PersonNumber=V3sg'],
#  ['kurIlAn',
#   'kur+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['bulunmAktayDI',
#   'bulun+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=PastCop+PersonNumber=V3pl'],
#  ['nerde',
#   'nere+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Loc+Copula=PresCop+PersonNumber=V3pl'],
#  ['demAsI',
#   'de+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Nom'],
#  ['gelsA',
#   'gel+VERB+Polarity=Pos+TenseAspectMood=Desr+Copula=PresCop+PersonNumber=V3sg'],
#  ['gerek',
#   'gerek+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=PresCop+PersonNumber=V3sg'],
#  ['etmAk',
#   'et+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['kullanmA',
#   'kullan+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['anlaşmAsI',
#   'anla+VERB+Derivation=Rcp+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Bare'],
#  ['yazmA',
#   'yaz+VERB+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare'],
#  ['yakalaDI',
#   'yakala+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg'],
#  ['kapaTIlDI',
#   'kapa+VERB+Derivation=Cau+Derivation=Pass+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3pl'],
#  ['bozIlmAsInA',
#   'boz+VERB+Derivation=Pass+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=P3sg+Case=Dat'],
#  ['denIr',
#   'de+VERB+Derivation=Pass+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg'],
#  ['oluşTIrIrDI',
#   'oluş+VERB+Derivation=Cau+Polarity=Pos+TenseAspectMood=Aor+Copula=PastCop+PersonNumber=V3pl'],
#  ['ayrılAn',
#   'ayır+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon'],
#  ['bulunmAktaDIr',
#   'bulun+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg'],
#  ['bekleDIKlArINI',
#   'bekle+VERB+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3pl+Case=Acc'],
#  ['göstermAkteDIr',
#   'göster+VERB+Polarity=Pos+TenseAspectMood=Prog2+Copula=GenCop+PersonNumber=V3sg'],
#  ...]

# %%
wiki_pairs[0]
# Out:
# ['Kemerlerini', 'kemer+NOUN+PersonNumber=A3sg+Possessive=P3pl+Case=Acc', '0']

# %%
def get_max_feat_count(pairs):
    
    try:
        morphs = [token[1] for token in pairs]
    except:
        morphs = [token[1] for token in pairs[:-1]]

    feat_len = [len(token.split("+")[2:]) for token in morphs]
    return max(feat_len)

# %%
from collections import defaultdict

def create_df_from_pairs(pairs):

    max_feat_length = 0

    dict_df = dict()
    dict_df["token"] = []
    dict_df["Lemma"] = []
    dict_df["POS"] = []
    dict_df.update({f"Feature_{i}":pd.Series([pd.NA for i in range(len(pairs[:-1]))]) for i in range(get_max_feat_count(pairs))})

    for idx,(token, morphs) in enumerate(pairs[:-1]):

        dict_df["token"].append(token)

        feats = morphs.split("+")

        dict_df["Lemma"].append(feats[0])
        dict_df["POS"].append(feats[1])

        for i,feat in enumerate(feats[2:]):
            dict_df[f"Feature_{i}"][idx] = feat

    df_pairs = pd.DataFrame(dict_df)

    return df_pairs

# %%
df_wiki = create_df_from_pairs(wiki_pairs)

# %%
df_wiki.head(10)
# Out:
#            token        Lemma   POS          Feature_0            Feature_1  \
# 0    kemerlArINI        kemer  NOUN  PersonNumber=A3sg      Possessive=P3pl
# 1         aralık       aralık  NOUN  PersonNumber=A3sg      Possessive=Pnon
# 2         ayINDA           ay  NOUN      Temporal=True    PersonNumber=A3sg
# 3             ki           ki     X               <NA>                 <NA>
# 4  armageddon'DA   armageddon  NOUN    Apostrophe=True    PersonNumber=A3sg
# 5           dört         dört   NUM               <NA>                 <NA>
# 6        takımIn        takım  NOUN  PersonNumber=A3sg      Possessive=Pnon
# 7      katılDIKI        katıl  VERB       Polarity=Pos  Derivation=PastPart
# 8    eliminasyon  eliminasyon  NOUN  PersonNumber=A3sg      Possessive=Pnon
# 9        maçINDA          maç  NOUN  PersonNumber=A3sg      Possessive=P3sg
#
#          Feature_2 Feature_3    Feature_4 Feature_5 Feature_6 Feature_7  \
# 0         Case=Acc      <NA>         <NA>      <NA>      <NA>      <NA>
# 1        Case=Bare      <NA>         <NA>      <NA>      <NA>      <NA>
# 2  Possessive=P3sg  Case=Loc         <NA>      <NA>      <NA>      <NA>
# 3             <NA>      <NA>         <NA>      <NA>      <NA>      <NA>
# 4  Possessive=Pnon  Case=Loc  Proper=True      <NA>      <NA>      <NA>
# 5             <NA>      <NA>         <NA>      <NA>      <NA>      <NA>
# 6         Case=Gen      <NA>         <NA>      <NA>      <NA>      <NA>
# 7  Possessive=P3sg      <NA>         <NA>      <NA>      <NA>      <NA>
# 8        Case=Bare      <NA>         <NA>      <NA>      <NA>      <NA>
# 9         Case=Loc      <NA>         <NA>      <NA>      <NA>      <NA>
#
#   Feature_8 Feature_9 Feature_10 Feature_11 Feature_12 Feature_13 Feature_14  \
# 0      <NA>      <NA>       <NA>       <NA>       <NA>       <NA>       <NA>
# 1      <NA>      <NA>       <NA>       <NA>       <NA>       <NA>       <NA>
# 2      <NA>      <NA>       <NA>       <NA>       <NA>       <NA>       <NA>
# 3      <NA>      <NA>       <NA>       <NA>       <NA>       <NA>       <NA>
# 4      <NA>      <NA>       <NA>       <NA>       <NA>       <NA>       <NA>
# 5      <NA>      <NA>       <NA>       <NA>       <NA>       <NA>       <NA>
# 6      <NA>      <NA>       <NA>       <NA>       <NA>       <NA>       <NA>
# 7      <NA>      <NA>       <NA>       <NA>       <NA>       <NA>       <NA>
# 8      <NA>      <NA>       <NA>       <NA>       <NA>       <NA>       <NA>
# 9      <NA>      <NA>       <NA>       <NA>       <NA>       <NA>       <NA>
#
#   Feature_15
# 0       <NA>
# 1       <NA>
# 2       <NA>
# 3       <NA>
# 4       <NA>
# 5       <NA>
# 6       <NA>
# 7       <NA>
# 8       <NA>
# 9       <NA>

# %%
df_web = create_df_from_pairs(web_pairs)

# %%
df_web.head(10)
# Out:
#           token     Lemma    POS             Feature_0        Feature_1  \
# 0         burDA       bur   PRON     PersonNumber=A3sg  Possessive=Pnon
# 1            da        da    PRT                  <NA>             <NA>
# 2        öylemi      öyle   VERB     PersonNumber=A3sg  Possessive=Pnon
# 3         yoksa     yoksa   CONJ  ConjunctionType=Coor             <NA>
# 4       kiloYlA      kilo   VERB     PersonNumber=A3sg  Possessive=Pnon
# 5            mı        mı    PRT                  <NA>             <NA>
# 6            \?         ?  PUNCT                  <NA>             <NA>
# 7  açıklAnmAYAn      açık   NOUN     PersonNumber=A3sg  Possessive=Pnon
# 8     sorulArIn      soru   NOUN     PersonNumber=A3pl  Possessive=Pnon
# 9     müfredatA  müfredat   NOUN     PersonNumber=A3sg  Possessive=Pnon
#
#    Feature_2        Feature_3          Feature_4     Feature_5  \
# 0   Case=Loc             <NA>               <NA>          <NA>
# 1       <NA>             <NA>               <NA>          <NA>
# 2  Case=Bare   Copula=PresCop  PersonNumber=V3sg          <NA>
# 3       <NA>             <NA>               <NA>          <NA>
# 4   Case=Ins   Copula=PresCop  PersonNumber=V3sg          <NA>
# 5       <NA>             <NA>               <NA>          <NA>
# 6       <NA>             <NA>               <NA>          <NA>
# 7  Case=Bare  Derivation=Make    Derivation=Pass  Polarity=Neg
# 8   Case=Gen             <NA>               <NA>          <NA>
# 9   Case=Dat             <NA>               <NA>          <NA>
#
#              Feature_6        Feature_7 Feature_8 Feature_9 Feature_10  \
# 0                 <NA>             <NA>      <NA>      <NA>       <NA>
# 1                 <NA>             <NA>      <NA>      <NA>       <NA>
# 2                 <NA>             <NA>      <NA>      <NA>       <NA>
# 3                 <NA>             <NA>      <NA>      <NA>       <NA>
# 4                 <NA>             <NA>      <NA>      <NA>       <NA>
# 5                 <NA>             <NA>      <NA>      <NA>       <NA>
# 6                 <NA>             <NA>      <NA>      <NA>       <NA>
# 7  Derivation=PresPart  Possessive=Pnon      <NA>      <NA>       <NA>
# 8                 <NA>             <NA>      <NA>      <NA>       <NA>
# 9                 <NA>             <NA>      <NA>      <NA>       <NA>
#
#   Feature_11 Feature_12 Feature_13
# 0       <NA>       <NA>       <NA>
# 1       <NA>       <NA>       <NA>
# 2       <NA>       <NA>       <NA>
# 3       <NA>       <NA>       <NA>
# 4       <NA>       <NA>       <NA>
# 5       <NA>       <NA>       <NA>
# 6       <NA>       <NA>       <NA>
# 7       <NA>       <NA>       <NA>
# 8       <NA>       <NA>       <NA>
# 9       <NA>       <NA>       <NA>

# %%
all_data = pd.concat([df_web, df_wiki], ignore_index=True)

# %%
all_data[all_data["POS"] == ""]
# Out:
# Empty DataFrame
# Columns: [token, Lemma, POS, Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12, Feature_13, Feature_14, Feature_15]
# Index: []

# %%
all_data.iloc[4461]["Lemma"] = "google+"
all_data.iloc[4461]["POS"] = "NOUN"
all_data.iloc[4461]["Feature_0"] = "PersonNumber=A3sg"
all_data.iloc[4461]["Feature_1"] = "Possessive=Pnon"
all_data.iloc[4461]["Feature_2"] = "Case=Bare"
all_data.iloc[4461]["Feature_3"] = pd.NA

# %%
all_data.fillna("Nan",inplace=True)
all_data.head()
# Out:
#      token  Lemma   POS             Feature_0        Feature_1  Feature_2  \
# 0    burDA    bur  PRON     PersonNumber=A3sg  Possessive=Pnon   Case=Loc
# 1       da     da   PRT                   Nan              Nan        Nan
# 2   öylemi   öyle  VERB     PersonNumber=A3sg  Possessive=Pnon  Case=Bare
# 3    yoksa  yoksa  CONJ  ConjunctionType=Coor              Nan        Nan
# 4  kiloYlA   kilo  VERB     PersonNumber=A3sg  Possessive=Pnon   Case=Ins
#
#         Feature_3          Feature_4 Feature_5 Feature_6 Feature_7 Feature_8  \
# 0             Nan                Nan       Nan       Nan       Nan       Nan
# 1             Nan                Nan       Nan       Nan       Nan       Nan
# 2  Copula=PresCop  PersonNumber=V3sg       Nan       Nan       Nan       Nan
# 3             Nan                Nan       Nan       Nan       Nan       Nan
# 4  Copula=PresCop  PersonNumber=V3sg       Nan       Nan       Nan       Nan
#
#   Feature_9 Feature_10 Feature_11 Feature_12 Feature_13 Feature_14 Feature_15
# 0       Nan        Nan        Nan        Nan        Nan        Nan        Nan
# 1       Nan        Nan        Nan        Nan        Nan        Nan        Nan
# 2       Nan        Nan        Nan        Nan        Nan        Nan        Nan
# 3       Nan        Nan        Nan        Nan        Nan        Nan        Nan
# 4       Nan        Nan        Nan        Nan        Nan        Nan        Nan

# %%
all_data["POS"].value_counts()
# Out:
# NOUN     28973
# VERB     11755
# PUNCT     9048
# ADJ       2943
# ADP       2761
# CONJ      2672
# DET       2421
# ADV       1591
# NUM       1534
# PRON      1284
# PRT       1005
# X          431
# ONOM        13
#              6
# AFFIX        3
# Name: POS, dtype: int64

# %%
feature_count = pd.Series(all_data[[f"Feature_{i}" for i in range(17)]].to_numpy().flatten()).value_counts(ascending=True)[1:]
feature_count
# Out:
# Derivation=Haste          1
# Derivation=Inter          3
# Derivation=Aff            3
# Derivation=Ever           3
# Derivation=Snd            4
#                       ...
# Polarity=Pos          11121
# Case=Bare             21802
# Possessive=Pnon       31038
# PersonNumber=A3sg     32354
# Nan                  753257
# Length: 111, dtype: int64

# %%
feature_count[-10:]
# Out:
# PersonNumber=V3sg      4249
# Case=Nom               4491
# Copula=PresCop         4706
# Proper=True            7370
# Possessive=P3sg        9089
# Polarity=Pos          10830
# Case=Bare             17684
# Possessive=Pnon       31039
# PersonNumber=A3sg     32354
# Nan                  753496
# dtype: int64

# %%
with open("feats.txt","w+", encoding="utf-8") as f_out:
    for feat in feature_count.index:
        f_out.write(f"\'{feat}\': r\'\'\n")

# %%
cropped = feature_count[:]
plt.rcParams['figure.figsize'] = [250, 3]
plt.bar(cropped.index, cropped.values)
# Out:
# <BarContainer object of 121 artists>

# %%
cropped
# Out:
# Derivation=ProNom           1
# ComplementType=CAcc         2
# Derivation=Inter            3
# Derivation=Aff              3
# X                           3
#                         ...
# Polarity=Pos            10830
# Case=Bare               17684
# Possessive=Pnon         31039
# PersonNumber=A3sg       32354
# Nan                    753496
# Length: 121, dtype: int64

# %%
def get_an_example(val_counts):
    samples = defaultdict(tuple)
    for feat, count in zip(val_counts.index, val_counts.values):
        ex = []
        for idx in range(16):
            results = all_data[all_data[f"Feature_{idx}"] == feat]
            if len(results) > 0:
                 ex.extend(results["token"])
                
        samples[f"{feat}"] = ex[0]
    return samples

# %%
for idx in range(16):
    results = all_data[all_data[f"Feature_{idx}"] == "Derivation=Lang"]
    if len(results) > 0:
         print(results["token"])
# Out:
# 1547       i̇ngilizCA
# 3988         arapCADA
# 6487           türkCA
# 6781     ingilizCAYlA
# 17935          türkCA
#              ...
# 63794    türkmenCA'DA
# 64993       çupikCAsI
# 65059       fransızCA
# 65067       fransızCA
# 65884          türkCA
# Name: token, Length: 76, dtype: object

# %%
def parse_rows(results):
    add_list = ["Lemma", "POS"]
    add_list.extend([f"Feature_{i}" for i in range(16)])
    data = []
    for i in results.index:
        data.append(" ".join([f"{token}" for token in all_data[add_list].loc[i].to_list() if token != "Nan"]))
    return data

# %%
train_pairs = [] 
val_pairs = []
test_pairs = []

dummy = all_data.copy(deep=True)

while dummy.shape[0] >= 1:
    try:
        feature_count = pd.Series(dummy[[f"Feature_{i}" for i in range(16)]].to_numpy().flatten()).value_counts(ascending=True)[:-1]

        feat = feature_count.index[0]
        indices = []
        data = []
        for idx in range(16):
            results = dummy[dummy[f"Feature_{idx}"] == feat]
            if len(results) > 0:
                data.extend(zip(list(results["token"]), parse_rows(results)))
                indices.extend(results.index)

        num_val_samples = int(0.15 * len(data))
        num_train_samples = len(data) - 2 * num_val_samples
        train_pairs.extend(data[:num_train_samples])
        val_pairs.extend(data[num_train_samples : num_train_samples + num_val_samples])
        test_pairs.extend(data[num_train_samples + num_val_samples :])

        dummy.drop(indices, inplace=True)
        print(feat)
        print("Remaining data:",dummy.shape[0])
        print("Remaining features:",len(feature_count))  
        print("*****************************")
        
    except:
        break
# Out:
# Derivation=ProNom
# Remaining data: 66441
# Remaining features: 111
# *****************************
# Derivation=Haste
# Remaining data: 66440
# Remaining features: 110
# *****************************
# Derivation=Ever
# Remaining data: 66437
# Remaining features: 109
# *****************************
# Derivation=Inter
# Remaining data: 66434
# Remaining features: 108
# *****************************
# Derivation=Aff
# Remaining data: 66431
# Remaining features: 107
# *****************************
# Derivation=Snd
# Remaining data: 66427
# Remaining features: 106
# *****************************
# Derivation=Coll
# Remaining data: 66423
# Remaining features: 105
# *****************************
# Derivation=Sim
# Remaining data: 66418
# Remaining features: 104
# *****************************
# Derivation=Like
# Remaining data: 66413
# Remaining features: 103
# *****************************
# Contrast=True
# Remaining data: 66408
# Remaining features: 102
# *****************************
# Derivation=Fam
# Remaining data: 66401
# Remaining features: 101
# *****************************
# NumberType=Dist
# Remaining data: 66393
# Remaining features: 100
# *****************************
# Derivation=Dim
# Remaining data: 66384
# Remaining features: 99
# *****************************
# Derivation=PerNom
# Remaining data: 66375
# Remaining features: 98
# *****************************
# Derivation=Doct
# Remaining data: 66362
# Remaining features: 97
# *****************************
# Derivation=Of
# Remaining data: 66348
# Remaining features: 96
# *****************************
# Derivation=Since
# Remaining data: 66333
# Remaining features: 95
# *****************************
# Derivation=AorNom
# Remaining data: 66316
# Remaining features: 94
# *****************************
# Derivation=True
# Remaining data: 66296
# Remaining features: 93
# *****************************
# Derivation=Act
# Remaining data: 66275
# Remaining features: 92
# *****************************
# Derivation=By
# Remaining data: 66254
# Remaining features: 91
# *****************************
# Derivation=Foll
# Remaining data: 66232
# Remaining features: 90
# *****************************
# Copula=EvCop
# Remaining data: 66207
# Remaining features: 89
# *****************************
# PersonNumber=A1pl
# Remaining data: 66181
# Remaining features: 88
# *****************************
# ConjunctionType=Sub
# Remaining data: 66151
# Remaining features: 87
# *****************************
# Derivation=As
# Remaining data: 66120
# Remaining features: 86
# *****************************
# TenseAspectMood=Opt
# Remaining data: 66087
# Remaining features: 85
# *****************************
# Derivation=AorPart
# Remaining data: 66046
# Remaining features: 84
# *****************************
# PersonNumber=A2sg
# Remaining data: 65999
# Remaining features: 83
# *****************************
# Derivation=When
# Remaining data: 65945
# Remaining features: 82
# *****************************
# PersonNumber=A2pl
# Remaining data: 65887
# Remaining features: 81
# *****************************
# Derivation=Ly
# Remaining data: 65828
# Remaining features: 80
# *****************************
# TenseAspectMood=Nec
# Remaining data: 65759
# Remaining features: 79
# *****************************
# Derivation=Lang
# Remaining data: 65684
# Remaining features: 78
# *****************************
# ConjunctionType=Par
# Remaining data: 65597
# Remaining features: 77
# *****************************
# Possessive=P2sg
# Remaining data: 65508
# Remaining features: 76
# *****************************
# TenseAspectMood=Desr
# Remaining data: 65415
# Remaining features: 75
# *****************************
# Derivation=For
# Remaining data: 65322
# Remaining features: 74
# *****************************
# Derivation=FutNom
# Remaining data: 65228
# Remaining features: 73
# *****************************
# Derivation=While
# Remaining data: 65132
# Remaining features: 72
# *****************************
# PersonNumber=V1pl
# Remaining data: 65035
# Remaining features: 71
# *****************************
# Derivation=Rfx
# Remaining data: 64926
# Remaining features: 70
# *****************************
# Derivation=PerPart
# Remaining data: 64815
# Remaining features: 69
# *****************************
# Derivation=From
# Remaining data: 64700
# Remaining features: 68
# *****************************
# Derivation=FutPart
# Remaining data: 64578
# Remaining features: 67
# *****************************
# DeterminerType=Def
# Remaining data: 64456
# Remaining features: 66
# *****************************
# PersonNumber=A1sg
# Remaining data: 64332
# Remaining features: 65
# *****************************
# Derivation=Bcm
# Remaining data: 64202
# Remaining features: 64
# *****************************
# Derivation=Rtd
# Remaining data: 64066
# Remaining features: 63
# *****************************
# Derivation=Rcp
# Remaining data: 63914
# Remaining features: 62
# *****************************
# Possessive=P1pl
# Remaining data: 63749
# Remaining features: 61
# *****************************
# Derivation=Inh
# Remaining data: 63581
# Remaining features: 60
# *****************************
# Derivation=Wout
# Remaining data: 63406
# Remaining features: 59
# *****************************
# Derivation=PresNom
# Remaining data: 63229
# Remaining features: 58
# *****************************
# NumberType=Ord
# Remaining data: 63051
# Remaining features: 57
# *****************************
# Derivation=Acq
# Remaining data: 62867
# Remaining features: 56
# *****************************
# TenseAspectMood=Fut
# Remaining data: 62684
# Remaining features: 55
# *****************************
# PersonNumber=V2sg
# Remaining data: 62489
# Remaining features: 54
# *****************************
# Copula=CndCop
# Remaining data: 62307
# Remaining features: 53
# *****************************
# Derivation=After
# Remaining data: 62107
# Remaining features: 52
# *****************************
# TenseAspectMood=Prog2
# Remaining data: 61862
# Remaining features: 51
# *****************************
# DeterminerType=Dem
# Remaining data: 61608
# Remaining features: 50
# *****************************
# Possessive=P1sg
# Remaining data: 61340
# Remaining features: 49
# *****************************
# Derivation=Agt
# Remaining data: 61068
# Remaining features: 48
# *****************************
# Possessive=P2pl
# Remaining data: 60776
# Remaining features: 47
# *****************************
# Derivation=PastPart
# Remaining data: 60514
# Remaining features: 46
# *****************************
# TenseAspectMood=Imp
# Remaining data: 60220
# Remaining features: 45
# *****************************
# PersonNumber=V2pl
# Remaining data: 60090
# Remaining features: 44
# *****************************
# Copula=PastCop
# Remaining data: 59784
# Remaining features: 43
# *****************************
# PersonNumber=V1sg
# Remaining data: 59439
# Remaining features: 42
# *****************************
# TenseAspectMood=Prog1
# Remaining data: 59147
# Remaining features: 41
# *****************************
# Derivation=Able
# Remaining data: 58844
# Remaining features: 40
# *****************************
# Polarity=Neg
# Remaining data: 58553
# Remaining features: 39
# *****************************
# Possessive=P3pl
# Remaining data: 58198
# Remaining features: 38
# *****************************
# ConjunctionType=Adv
# Remaining data: 57839
# Remaining features: 37
# *****************************
# Derivation=Cau
# Remaining data: 57436
# Remaining features: 36
# *****************************
# Derivation=PastNom
# Remaining data: 57039
# Remaining features: 35
# *****************************
# Derivation=Inf
# Remaining data: 56636
# Remaining features: 34
# *****************************
# Derivation=Make
# Remaining data: 56230
# Remaining features: 33
# *****************************
# Derivation=Rel
# Remaining data: 55757
# Remaining features: 32
# *****************************
# TenseAspectMood=Nar
# Remaining data: 55265
# Remaining features: 31
# *****************************
# DeterminerType=Ind
# Remaining data: 54751
# Remaining features: 30
# *****************************
# Derivation=Ger
# Remaining data: 54223
# Remaining features: 29
# *****************************
# Temporal=True
# Remaining data: 53681
# Remaining features: 28
# *****************************
# PersonNumber=V3pl
# Remaining data: 53107
# Remaining features: 27
# *****************************
# TenseAspectMood=Aor
# Remaining data: 52616
# Remaining features: 26
# *****************************
# Copula=GenCop
# Remaining data: 52118
# Remaining features: 25
# *****************************
# Derivation=Pass
# Remaining data: 51538
# Remaining features: 24
# *****************************
# TenseAspectMood=Past
# Remaining data: 50988
# Remaining features: 23
# *****************************
# PersonNumber=V3sg
# Remaining data: 50516
# Remaining features: 22
# *****************************
# Case=Ins
# Remaining data: 49876
# Remaining features: 20
# *****************************
# Derivation=Ness
# Remaining data: 49222
# Remaining features: 19
# *****************************
# Derivation=PresPart
# Remaining data: 48452
# Remaining features: 18
# *****************************
# Derivation=With
# Remaining data: 47563
# Remaining features: 17
# *****************************
# Polarity=Pos
# Remaining data: 46582
# Remaining features: 16
# *****************************
# Derivation=Nonf
# Remaining data: 46581
# Remaining features: 15
# *****************************
# Case=Abl
# Remaining data: 45537
# Remaining features: 14
# *****************************
# Apostrophe=True
# Remaining data: 44085
# Remaining features: 13
# *****************************
# Case=Acc
# Remaining data: 42724
# Remaining features: 12
# *****************************
# Case=Gen
# Remaining data: 41138
# Remaining features: 11
# *****************************
# Case=Dat
# Remaining data: 39296
# Remaining features: 10
# *****************************
# PersonNumber=A3pl
# Remaining data: 37586
# Remaining features: 9
# *****************************
# Case=Loc
# Remaining data: 35692
# Remaining features: 8
# *****************************
# Possessive=P3sg
# Remaining data: 33507
# Remaining features: 7
# *****************************
# Case=Nom
# Remaining data: 31747
# Remaining features: 6
# *****************************
# ConjunctionType=Coor
# Remaining data: 29551
# Remaining features: 5
# *****************************
# Proper=True
# Remaining data: 25517
# Remaining features: 4
# *****************************
# PersonNumber=A3sg
# Remaining data: 19161
# Remaining features: 3
# *****************************
# Case=Bare
# Remaining data: 17463
# Remaining features: 2
# *****************************

# %%
pos_count = dummy["POS"].value_counts(ascending=True)

for pos in pos_count.index:
    
    indices = []
    data = []
    results = dummy[dummy[f"POS"] == pos]

    data.extend(zip(list(results["token"]), parse_rows(results)))
    indices.extend(results.index)

    num_val_samples = int(0.15 * len(data))
    num_train_samples = len(data) - 2 * num_val_samples
    train_pairs.extend(data[:num_train_samples])
    val_pairs.extend(data[num_train_samples : num_train_samples + num_val_samples])
    test_pairs.extend(data[num_train_samples + num_val_samples :])

    dummy.drop(indices, inplace=True)
    print(pos)
    print("Remaining data:",dummy.shape[0])
    print("Remaining features:",len(pos_count))  
    print("*****************************")
# Out:
# AFFIX
# Remaining data: 17460
# Remaining features: 12
# *****************************
# ONOM
# Remaining data: 17451
# Remaining features: 12
# *****************************
# DET^Def
# Remaining data: 17329
# Remaining features: 12
# *****************************
# DET
# Remaining data: 17170
# Remaining features: 12
# *****************************
# X
# Remaining data: 16905
# Remaining features: 12
# *****************************
# DET^Dem
# Remaining data: 16458
# Remaining features: 12
# *****************************
# DET^Ind
# Remaining data: 15657
# Remaining features: 12
# *****************************
# PRT
# Remaining data: 14652
# Remaining features: 12
# *****************************
# NUM
# Remaining data: 13353
# Remaining features: 12
# *****************************
# ADV
# Remaining data: 11820
# Remaining features: 12
# *****************************
# ADJ
# Remaining data: 9050
# Remaining features: 12
# *****************************
# PUNCT
# Remaining data: 0
# Remaining features: 12
# *****************************

# %%
print(len(dummy))
# Out:
# 0

# %%
print(f"""
Size of training data: {len(train_pairs)} {len(train_pairs)/all_data.shape[0]}
Size of validation data: {len(val_pairs)} {len(val_pairs)/all_data.shape[0]}
Size of training data: {len(test_pairs)} {len(test_pairs)/all_data.shape[0]}
""")
print(all_data.shape[0])
print(len(train_pairs)+ len(val_pairs) + len(test_pairs))
# Out:
# Size of training data: 46627 0.701769964781313
# Size of validation data: 9911 0.14916769513259684
# Size of training data: 9911 0.14916769513259684
#
# 66442
# 66449

# %%
train_final = []
for p in train_pairs:
    train_final.extend(p)
    
val_final = []
for p in val_pairs:
    val_final.extend(p)

test_final = []
for p in test_pairs:
    test_final.extend(p)

# %%
train_pairs = train_final
val_pairs = val_final
test_pairs = test_final

# %%
with open("/home/kara/Documents/Courses/Fall 2021/LING412 - RESEARCH & WRITING/Datasets/Phonological/Distributed/train.txt","w+", encoding="utf-8") as f_out:
    for token, feat in train_pairs:
        f_out.write(f"{token}\t{'+'.join(feat.split())}\n")
        
with open("/home/kara/Documents/Courses/Fall 2021/LING412 - RESEARCH & WRITING/Datasets/Phonological/Distributed/val.txt","w+", encoding="utf-8") as f_out:
    for token,feat in val_pairs:
        f_out.write(f"{token}\t{'+'.join(feat.split())}\n")
        
with open("/home/kara/Documents/Courses/Fall 2021/LING412 - RESEARCH & WRITING/Datasets/Phonological/Distributed/test.txt","w+", encoding="utf-8") as f_out:
    for token,feat in test_pairs:
        f_out.write(f"{token}\t{'+'.join(feat.split())}\n")

# %%
get_an_example(cropped[:])
# Out:
# defaultdict(tuple,
#             {'PersonNumber=V1pl': 'biliyoruzdur',
#              'Derivation=From': 'Yerli',
#              'Derivation=Rfx': 'sevinirim',
#              'Derivation=PerPart': 'korkmuş',
#              'Derivation=While': 'iken',
#              'Derivation=FutNom': 'olacağını',
#              'Derivation=For': ")'lik",
#              'TenseAspectMood=Desr': 'etsem',
#              'Possessive=P2sg': 'Aygıtınız',
#              'ComplementType=CIns': 'birlikte',
#              'ConjunctionType=Par': 'ne',
#              'Derivation=Lang': 'İngilizce',
#              'TenseAspectMood=Nec': 'kullanmamalısınız',
#              'PersonNumber=A2pl': 'sizlerle',
#              'Derivation=Ly': 'olasıca',
#              'Derivation=When': 'deyince',
#              'PersonNumber=A2sg': 'seninle',
#              'Derivation=AorPart': 'güler',
#              'ComplementType=CFin': 'diye',
#              'TenseAspectMood=Opt': 'Diyelimki',
#              'Derivation=As': 'oldukça',
#              'ConjunctionType=Sub': 'ki',
#              'PersonNumber=A1pl': 'hepimiz',
#              'ComplementType=CNum': 'defa',
#              'Copula=EvCop': 'gerekiyormuş',
#              'Derivation=Foll': 'terapistiniz',
#              'Derivation=Act': 'bence',
#              'Derivation=By': 'kendimce',
#              'Derivation=True': "802'deki",
#              'Derivation=AorNom': 'geçerlidir',
#              'Derivation=Since': 'süredir',
#              'Derivation=Of': 'binlerce',
#              'Derivation=Doct': 'atletizm',
#              'Derivation=PerNom': 'almışlardan',
#              'Derivation=Dim': 'kitapçığına',
#              'NumberType=Dist': 'birer',
#              'Derivation=Fam': 'baklagiller',
#              'Derivation=Sim': 'ipeksi',
#              'Contrast=True': 'niyeyse',
#              'Derivation=Like': 'açıkçası',
#              'Derivation=Coll': 'çokça',
#              'NOUN': 'rh+',
#              'Derivation=Snd': 'çatlıyor',
#              'Derivation=Aff': 'ikincil',
#              'X': '+',
#              'Derivation=Ever': 'süregelmişti',
#              'Derivation=Inter': 'biraraya',
#              'ComplementType=CAcc': 'aşkın',
#              'Derivation=ProNom': 'ölesiye',
#              'Derivation=Haste': 'ölüverdiler'})

# %%
feature_index = pd.Series(all_data[[f"Feature_{i}" for i in range(16)]].to_numpy().flatten()).index
feature_index
# Out:
# RangeIndex(start=0, stop=1063040, step=1)

# %%
train_pairs[0][1].split()[1]
# Out:
# 'VERB'

# %%
train_pos = pd.Series([token[1].split(" ")[1] for token in train_pairs]).value_counts()
val_pos =  pd.Series([token[1].split(" ")[1] for token in val_pairs]).value_counts()
test_pos =  pd.Series([token[1].split(" ")[1] for token in test_pairs]).value_counts()

# %%
_,train_feats = get_tag_counts(train_pairs)
_,val_feats = get_tag_counts(val_pairs)
_,test_feats = get_tag_counts(test_pairs)

# %%
for idx in val_feats.index:
    print(f"{idx}:\t\tTrain:{train_feats[idx]} Val:{val_feats[idx]} Test:{test_feats[idx]}")
    print("********************")
# Out:
# PersonNumber=A3sg:		Train:22043 Val:4778 Test:5533
# ********************
# Possessive=Pnon:		Train:21425 Val:4511 Test:5107
# ********************
# Case=Bare:		Train:14649 Val:3278 Test:3876
# ********************
# Polarity=Pos:		Train:7657 Val:1715 Test:1907
# ********************
# Possessive=P3sg:		Train:6099 Val:1461 Test:1529
# ********************
# Proper=True:		Train:4558 Val:1206 Test:1606
# ********************
# Copula=PresCop:		Train:3380 Val:673 Test:654
# ********************
# PersonNumber=V3sg:		Train:2985 Val:668 Test:598
# ********************
# Case=Nom:		Train:3225 Val:631 Test:635
# ********************
# PersonNumber=A3pl:		Train:2870 Val:602 Test:592
# ********************
# Case=Loc:		Train:2487 Val:543 Test:596
# ********************
# Derivation=Pass:		Train:847 Val:495 Test:710
# ********************
# Case=Dat:		Train:1987 Val:389 Test:417
# ********************
# Case=Gen:		Train:1773 Val:377 Test:378
# ********************
# ConjunctionType=Coor:		Train:1538 Val:329 Test:329
# ********************
# Case=Acc:		Train:1617 Val:314 Test:327
# ********************
# ComplementType=CBare:		Train:1356 Val:297 Test:245
# ********************
# Derivation=Nonf:		Train:1180 Val:289 Test:421
# ********************
# Apostrophe=True:		Train:1032 Val:276 Test:484
# ********************
# Copula=GenCop:		Train:974 Val:256 Test:253
# ********************
# TenseAspectMood=Aor:		Train:1090 Val:217 Test:231
# ********************
# Derivation=Cau:		Train:460 Val:213 Test:215
# ********************
# Case=Abl:		Train:934 Val:202 Test:199
# ********************
# Derivation=PresPart:		Train:891 Val:200 Test:192
# ********************
# DeterminerType=Ind:		Train:922 Val:197 Test:197
# ********************
# PersonNumber=V3pl:		Train:917 Val:193 Test:217
# ********************
# TenseAspectMood=Past:		Train:922 Val:164 Test:170
# ********************
# Derivation=Able:		Train:288 Val:141 Test:191
# ********************
# Derivation=With:		Train:643 Val:134 Test:288
# ********************
# Derivation=PastNom:		Train:353 Val:122 Test:142
# ********************
# TenseAspectMood=Nar:		Train:537 Val:120 Test:109
# ********************
# Polarity=Neg:		Train:528 Val:120 Test:104
# ********************
# Temporal=True:		Train:429 Val:120 Test:92
# ********************
# Derivation=Ness:		Train:535 Val:116 Test:229
# ********************
# Case=Ins:		Train:511 Val:113 Test:108
# ********************
# DeterminerType=Dem:		Train:492 Val:105 Test:105
# ********************
# Derivation=Ger:		Train:450 Val:93 Test:89
# ********************
# Derivation=PastPart:		Train:225 Val:82 Test:48
# ********************
# TenseAspectMood=Prog1:		Train:469 Val:72 Test:75
# ********************
# Possessive=P3pl:		Train:292 Val:71 Test:62
# ********************
# Derivation=Rel:		Train:361 Val:70 Test:72
# ********************
# Derivation=Inf:		Train:351 Val:70 Test:79
# ********************
# Derivation=Make:		Train:288 Val:66 Test:414
# ********************
# TenseAspectMood=Imp:		Train:301 Val:60 Test:56
# ********************
# Copula=PastCop:		Train:280 Val:57 Test:54
# ********************
# PersonNumber=V2pl:		Train:330 Val:56 Test:71
# ********************
# PersonNumber=V1sg:		Train:338 Val:55 Test:59
# ********************
# ConjunctionType=Adv:		Train:253 Val:53 Test:53
# ********************
# ComplementType=CDat:		Train:244 Val:52 Test:52
# ********************
# Possessive=P2pl:		Train:236 Val:50 Test:45
# ********************
# Possessive=P1sg:		Train:198 Val:42 Test:40
# ********************
# TenseAspectMood=Prog2:		Train:188 Val:41 Test:38
# ********************
# Derivation=Agt:		Train:193 Val:41 Test:42
# ********************
# DeterminerType=Def:		Train:172 Val:36 Test:36
# ********************
# ComplementType=CAbl:		Train:154 Val:33 Test:33
# ********************
# Copula=CndCop:		Train:165 Val:31 Test:32
# ********************
# Derivation=After:		Train:146 Val:30 Test:30
# ********************
# PersonNumber=V2sg:		Train:155 Val:30 Test:35
# ********************
# TenseAspectMood=Fut:		Train:149 Val:29 Test:28
# ********************
# Derivation=Rcp:		Train:113 Val:27 Test:30
# ********************
# Derivation=Acq:		Train:131 Val:27 Test:41
# ********************
# NumberType=Ord:		Train:126 Val:26 Test:26
# ********************
# Derivation=PresNom:		Train:127 Val:26 Test:27
# ********************
# Derivation=Wout:		Train:124 Val:26 Test:32
# ********************
# Derivation=Inh:		Train:123 Val:25 Test:25
# ********************
# Possessive=P1pl:		Train:122 Val:24 Test:25
# ********************
# ComplementType=CGen:		Train:104 Val:21 Test:21
# ********************
# Derivation=Rfx:		Train:79 Val:20 Test:16
# ********************
# Derivation=Bcm:		Train:93 Val:20 Test:26
# ********************
# Derivation=Rtd:		Train:96 Val:20 Test:20
# ********************
# PersonNumber=A1sg:		Train:98 Val:19 Test:19
# ********************
# Derivation=FutPart:		Train:88 Val:18 Test:18
# ********************
# PersonNumber=V1pl:		Train:87 Val:18 Test:17
# ********************
# Derivation=From:		Train:81 Val:17 Test:17
# ********************
# Derivation=PerPart:		Train:81 Val:16 Test:16
# ********************
# Derivation=While:		Train:69 Val:14 Test:14
# ********************
# Derivation=FutNom:		Train:66 Val:14 Test:14
# ********************
# Possessive=P2sg:		Train:63 Val:14 Test:13
# ********************
# TenseAspectMood=Desr:		Train:67 Val:13 Test:13
# ********************
# ConjunctionType=Par:		Train:61 Val:13 Test:13
# ********************
# Derivation=For:		Train:67 Val:13 Test:13
# ********************
# ComplementType=CIns:		Train:61 Val:13 Test:13
# ********************
# Derivation=Lang:		Train:53 Val:11 Test:12
# ********************
# TenseAspectMood=Nec:		Train:49 Val:10 Test:10
# ********************
# PersonNumber=A2pl:		Train:45 Val:10 Test:10
# ********************
# Derivation=When:		Train:38 Val:8 Test:8
# ********************
# Derivation=Ly:		Train:43 Val:8 Test:8
# ********************
# PersonNumber=A2sg:		Train:34 Val:7 Test:7
# ********************
# Derivation=AorPart:		Train:29 Val:6 Test:6
# ********************
# ComplementType=CFin:		Train:24 Val:5 Test:5
# ********************
# ConjunctionType=Sub:		Train:22 Val:4 Test:4
# ********************
# Derivation=As:		Train:23 Val:4 Test:4
# ********************
# TenseAspectMood=Opt:		Train:25 Val:4 Test:4
# ********************
# PersonNumber=A1pl:		Train:20 Val:3 Test:3
# ********************
# Derivation=Foll:		Train:16 Val:3 Test:3
# ********************
# ComplementType=CNum:		Train:20 Val:3 Test:3
# ********************
# Copula=EvCop:		Train:19 Val:3 Test:3
# ********************
# Derivation=Act:		Train:15 Val:3 Test:3
# ********************
# Derivation=By:		Train:15 Val:3 Test:3
# ********************
# Derivation=True:		Train:14 Val:3 Test:3
# ********************
# Derivation=Since:		Train:11 Val:2 Test:2
# ********************
# Derivation=AorNom:		Train:13 Val:2 Test:2
# ********************
# Derivation=Of:		Train:10 Val:2 Test:2
# ********************
# Derivation=Doct:		Train:11 Val:1 Test:1
# ********************
# NumberType=Dist:		Train:6 Val:1 Test:1
# ********************
# Derivation=Dim:		Train:7 Val:1 Test:1
# ********************
# Derivation=PerNom:		Train:8 Val:1 Test:1
# ********************
# Derivation=Fam:		Train:5 Val:1 Test:1
# ********************

# %%
plt.rcParams['figure.figsize'] = [50, 45]

plt.bar(train_pos.index, train_pos.values, label = "train_dist")
plt.bar(val_pos.index, val_pos.values, label = "val_dist")
plt.bar(test_pos.index, test_pos.values, label = "test_dist")
plt.legend()
plt.show()

# %%
plt.rcParams['figure.figsize'] = [250, 13]

plt.bar(train_feats[10:].index, train_feats[10:].values, label = "train_dist")
plt.bar(val_feats[10:].index, val_feats[10:].values, label = "val_dist")
plt.bar(test_feats[10:].index, test_feats[10:].values, label = "test_dist")
plt.legend()
plt.show()

# %%
pd.DataFrame({"TRAIN": train_pos,
             "VAL": val_pos,
             "TEST": test_pos}, dtype="int64").sort_values(by="TRAIN",ascending=False).head(20)
# Out:
#        TRAIN     VAL    TEST
# NOUN   19979  4232.0  4761.0
# VERB    8400  1889.0  1473.0
# PUNCT   6334  1357.0  1357.0
# ADJ     2106   422.0   415.0
# ADP     1965   424.0   372.0
# CONJ    1874   399.0   399.0
# DET     1699   361.0   361.0
# ADV     1126   232.0   233.0
# NUM     1093   220.0   221.0
# PRON     989   171.0   124.0
# PRT      705   150.0   150.0
# X        340    50.0    41.0
# ONOM      11     1.0     1.0
#            7     NaN     NaN
# AFFIX      3     NaN     NaN

# %%
pd.DataFrame({"TRAIN": train_feats,
             "VAL": val_feats,
             "TEST": test_feats}, dtype="int64").sort_values(by="TRAIN",ascending=False).head(20)
# Out:
#                       TRAIN     VAL    TEST
# PersonNumber=A3sg     22043  4778.0  5533.0
# Possessive=Pnon       21425  4511.0  5107.0
# Case=Bare             14649  3278.0  3876.0
# Polarity=Pos           7657  1715.0  1907.0
# Possessive=P3sg        6099  1461.0  1529.0
# Proper=True            4558  1206.0  1606.0
# Copula=PresCop         3380   673.0   654.0
# Case=Nom               3225   631.0   635.0
# PersonNumber=V3sg      2985   668.0   598.0
# PersonNumber=A3pl      2870   602.0   592.0
# Case=Loc               2487   543.0   596.0
# Case=Dat               1987   389.0   417.0
# Case=Gen               1773   377.0   378.0
# Case=Acc               1617   314.0   327.0
# ConjunctionType=Coor   1538   329.0   329.0
# ComplementType=CBare   1356   297.0   245.0
# Derivation=Nonf        1180   289.0   421.0
# TenseAspectMood=Aor    1090   217.0   231.0
# Apostrophe=True        1032   276.0   484.0
# Copula=GenCop           974   256.0   253.0

# %%
import random
num_to_select = 100                           # set the number to select here.
list_of_random_items = random.sample(web_pairs, num_to_select)

# %%
sentences ={}
with open("Data/Usable/web_sentences.txt","r",encoding="utf-8") as fin:
    sentences = {str(id): sent for sent,id  in [i.split("\t") for i in fin.read().split("\n")] }

# %%
for item in list_of_random_items:
    print(item)
# Out:
# ['Bu', 'bu+DET+DeterminerType=Dem', '2041']
# ['oyunu', 'oyun+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Nom', '912']
# ['ÖNERİSİ', 'öneri+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare', '1253']
# ['Hemen', 'hemen+ADV', '125']
# ['kek', 'kek+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare', '478']
# ['performans', 'performans+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare', '2092']
# ['kimden', 'kim+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Abl', '933']
# ['eğitimlerini', 'eğitim+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Acc', '1875']
# ['.', '.+PUNCT', '1450']
# ['takımında', 'takım+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Loc', '1647']
# ['şansına', 'şans+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Dat', '896']
# ['ki', 'ki+CONJ+ConjunctionType=Sub', '1311']
# ['çeşitli', 'çeşit+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=With', '1752']
# ['NE', 'ne+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Bare', '772']
# ['kalkarak', 'kalk+VERB+Polarity=Pos+Derivation=Ger', '1413']
# ['düşen', 'düş+VERB+Polarity=Pos+Derivation=PresNom+PersonNumber=A3sg+Possessive=Pnon+Case=Nom', '289']
# ['zencileri', 'zenci+NOUN+PersonNumber=A3pl+Possessive=Pnon+Case=Acc', '347']
# ['klinik', 'klinik+ADJ', '953']
# ['daha', 'daha+ADV', '1299']
# ['yüzündeki', 'yüz+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Loc+Derivation=Rel', '2355']
# ['yönüyle', 'yön+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Ins', '2105']
# ['şampiyon', 'şampiyon+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare', '1637']
# ['rüyada', 'rüya+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc', '819']
# ['çıkan', 'çık+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon', '2132']
# ['tutulmuş', 'tut+VERB+Derivation=Pass+Polarity=Pos+Derivation=PerNom+PersonNumber=A3sg+Possessive=Pnon+Case=Bare', '1997']
# ['girmeden', 'gir+VERB+Polarity=Neg+Derivation=Ger', '892']
# ['için', 'için+ADP+ComplementType=CBare+Possessive=Pnon+Case=Bare', '2474']
# ['yukarısından', 'yukarı+ADP+ComplementType=CGen+Possessive=P3sg+Case=Abl', '2485']
# ['veya', 'veya+CONJ+ConjunctionType=Coor', '851']
# ['karşı', 'karşı+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare', '960']
# ['cildinde', 'cilt+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Loc', '1498']
# ['Öğretmenleri', 'öğretmen+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Bare', '343']
# ['sitede', 'site+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Loc', '302']
# ['Bu', 'bu+DET+DeterminerType=Dem', '1502']
# [':', ':+PUNCT', '2143']
# ['süren', 'sür+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon', '2148']
# ['yol', 'yol+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare', '240']
# ['iç', 'iç+ADJ', '72']
# ['ince', 'ince+ADJ', '457']
# ['denilen', 'de+VERB+Derivation=Pass+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon', '1448']
# ['.', '.+PUNCT', '1932']
# ['başaramadığı', 'başar+VERB+Derivation=Able+Polarity=Neg+Derivation=PastPart+Possessive=P3sg', '1684']
# ['mı', 'mı+PRT', '1513']
# ['.', '.+PUNCT', '1840']
# [',', ',+PUNCT', '2139']
# ['.', '.+PUNCT', '837']
# ['demek', 'de+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Nom', '1102']
# [',', ',+PUNCT', '83']
# ['uğraş', 'uğraş+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare', '1564']
# ['olan', 'ol+VERB+Polarity=Pos+Derivation=PresPart+Possessive=Pnon', '961']
# ['çok', 'çok+ADV', '995']
# ['Onlar', 'onlar+PRON+PersonNumber=A3pl+Possessive=Pnon+Case=Nom', '2035']
# ['dağıtmak', 'dağıt+VERB+Polarity=Pos+Derivation=Inf+PersonNumber=A3sg+Possessive=Pnon+Case=Bare', '2278']
# ['arası', 'ara+ADP+ComplementType=CBare+Possessive=P3sg+Case=Bare', '1024']
# ['Ligi', 'lig+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare+Proper=True', '370']
# ['işaretleyin', 'işaret+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Make+Polarity=Pos+TenseAspectMood=Imp+Copula=PresCop+PersonNumber=V2pl', '1378']
# ['iyi', 'iyi+ADJ', '2326']
# ['.', '.+PUNCT', '468']
# ['yöntemdir', 'yöntem+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3sg', '847']
# ['sendromu', 'sendrom+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Bare', '913']
# ['bütün', 'bütün+DET+DeterminerType=Def', '1413']
# ['biraz', 'biraz+DET+DeterminerType=Ind', '1335']
# ['insan', 'insan+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare', '179']
# ['ULAŞTIRILIR', 'ulaş+VERB+Derivation=Cau+Derivation=Pass+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3pl', '2273']
# ['onun', 'onun+PRON+PersonNumber=A3sg+Possessive=Pnon+Case=Bare', '1697']
# ['bir', 'bir+DET+DeterminerType=Ind', '847']
# ['Zamparalığın', 'zampara+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Ness+PersonNumber=A3sg+Possessive=Pnon+Case=Gen', '1694']
# ['görüldüğü', 'gör+VERB+Derivation=Pass+Polarity=Pos+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3sg+Case=Bare', '718']
# ['virüsleri', 'virüs+NOUN+PersonNumber=A3pl+Possessive=P3sg+Case=Nom', '890']
# ['boy', 'boy+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare', '584']
# ['veya', 'veya+CONJ+ConjunctionType=Coor', '2526']
# ['yeminnen', 'yemin+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Ins', '46']
# ['.', '.+PUNCT', '236']
# ['oldu', 'ol+VERB+Polarity=Pos+TenseAspectMood=Past+Copula=PresCop+PersonNumber=V3sg', '137']
# ['ve', 've+CONJ+ConjunctionType=Coor', '2464']
# ['Benzin', 'benzin+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare', '962']
# ['kanserleşme', 'kanser+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Derivation=Bcm+Polarity=Pos+Derivation=Nonf+PersonNumber=A3sg+Possessive=Pnon+Case=Nom', '2027']
# ['etkinken', 'etkin+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=PresCop+PersonNumber=V3sg', '2458']
# ['Bedenin', 'beden+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Gen', '670']
# ['eski', 'eski+ADJ', '1930']
# ['biçiminde', 'biçim+NOUN+PersonNumber=A3sg+Possessive=P3sg+Case=Loc', '718']
# ['numaradan', 'numara+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Abl', '1499']
# ['alabilir', 'al+VERB+Polarity=Pos+Derivation=Able+Polarity=Pos+TenseAspectMood=Aor+Copula=PresCop+PersonNumber=V3sg', '705']
# ['yasaktır', 'yasak+VERB+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=GenCop+PersonNumber=V3pl', '170']
# ["Fernandao'nun", 'fernandao+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Gen+Proper=True', '1829']
# ['Ben', 'ben+PRON+PersonNumber=A1sg+Possessive=Pnon+Case=Nom', '437']
# ["Arapgir'li", 'arapgir+NOUN+Apostrophe=True+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Proper=True+Derivation=From+PersonNumber=A3sg+Possessive=Pnon+Case=Bare+Copula=PresCop+PersonNumber=V3sg', '1865']
# ['.', '.+PUNCT', '1967']
# ['fn', 'fn+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Bare', '1483']
# ['üzerine', 'üzer+ADP+ComplementType=CGen+Possessive=P3sg+Case=Dat', '1402']
# ['ile', 'ile+ADP+ComplementType=CBare+Possessive=Pnon+Case=Bare', '1691']
# ['Forumumuzu', 'forum+NOUN+PersonNumber=A3sg+Possessive=P1pl+Case=Acc', '275']
# ['alismadiklari', 'alış+VERB+Polarity=Neg+Derivation=PastNom+PersonNumber=A3sg+Possessive=P3pl+Case=Bare', '208']
# ['ve', 've+CONJ+ConjunctionType=Coor', '392']
# ['bir', 'bir+DET+DeterminerType=Ind', '2347']
# ['.', '.+PUNCT', '1286']
# ['ve', 've+CONJ+ConjunctionType=Coor', '1615']
# ['ytlye', 'ytl+NOUN+PersonNumber=A3sg+Possessive=Pnon+Case=Dat', '1870']
# ['yapilan', 'yap+VERB+Derivation=Pass+Polarity=Pos+Derivation=PresPart+Possessive=Pnon', '489']
# ['Her', 'her+DET+DeterminerType=Def', '1687']
